# %% [markdown]
# # Load description for each variable in each pair
#
# Recreates and extends analysis from https://github.com/amit-sharma/chatgpt-causality-pairs
# Focuses on analysis of the Tübingen dataset from https://webdav.tuebingen.mpg.de/cause-effect/

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#pip install '/content/drive/MyDrive/pywhy-llm'

# %%
#pip install guidance

# %%
#pip install python-dotenv

# %%
import sys
import os
import time


# Add the notebook setup path to sys.path
notebook_setup_path = os.path.abspath("../")
sys.path.insert(0, notebook_setup_path)

from notebook_setup import setup_local_pywhyllm
project_root = setup_local_pywhyllm()
# Out:
# 📋 Current sys.path before adding project root:
#   0: /home/moleropa/repositories/master/TFM/pywhyllm/docs/notebooks
#   1: /home/moleropa/miniforge3/envs/tfmenv/lib/python311.zip
#   2: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11
#   3: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11/lib-dynload
#   4:
#   5: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11/site-packages
#
# 🎯 Project root to add: /home/moleropa/repositories/master/TFM/pywhyllm
# ✅ Added local pywhyllm source to Python path: /home/moleropa/repositories/master/TFM/pywhyllm
#
# 📋 Updated sys.path after adding project root:
#   0: /home/moleropa/repositories/master/TFM/pywhyllm ⭐
#   1: /home/moleropa/repositories/master/TFM/pywhyllm/docs/notebooks
#   2: /home/moleropa/miniforge3/envs/tfmenv/lib/python311.zip
#   3: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11
#   4: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11/lib-dynload
#   5:
#   6: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11/site-packages
# 📋 Current sys.path before adding project root:
#   0: /home/moleropa/repositories/master/TFM/pywhyllm
#   1: /home/moleropa/repositories/master/TFM/pywhyllm/docs/notebooks
#   2: /home/moleropa/miniforge3/envs/tfmenv/lib/python311.zip
#   3: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11
#   4: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11/lib-dynload
#   5:
#   6: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11/site-packages
#
# 🎯 Project root to add: /home/moleropa/repositories/master/TFM/pywhyllm
# ✅ Local pywhyllm source already in Python path
#
# 📋 Updated sys.path after adding project root:
#   0: /home/moleropa/repositories/master/TFM/pywhyllm ⭐
#   1: /home/moleropa/repositories/master/TFM/pywhyllm/docs/notebooks
#   2: /home/moleropa/miniforge3/envs/tfmenv/lib/python311.zip
#   3: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11
#   4: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11/lib-dynload
#   5:
#   6: /home/moleropa/miniforge3/envs/tfmenv/lib/python3.11/site-packages

# %%
from dotenv import load_dotenv
from typing import Dict, List, Tuple
import guidance
import os

from openai import OpenAI
from portkey_ai import createHeaders


load_dotenv()
# Out:
# True

# %%
azure_model= "gpt-4o-mini" #"GPT-4o-2024-05-13" 
us_base_url = "https://us.aigw.galileo.roche.com/v1"

portkey_headers = createHeaders(config=os.environ["PORTKEY_AZURE_US_CONFIG"])
# azure_openai_client = OpenAI(base_url=us_base_url,
#             api_key=os.environ["PORTKEY_AZURE_US_API_KEY"],
#             default_headers=portkey_headers)


# Guidance con modelo OpenAI + base_url + headers
model = guidance.models.OpenAI(
    #"GPT-4o-2024-05-13",
    azure_model,
    api_key=os.environ["PORTKEY_AZURE_US_API_KEY"],
    base_url=us_base_url,
    default_headers=portkey_headers,
)

azure_model= "gpt-4o-mini" #"GPT-4o-2024-05-13" 
us_base_url = "https://us.aigw.galileo.roche.com/v1"
portkey_headers = createHeaders(config=os.environ["PORTKEY_AZURE_US_CONFIG"])

azure_openai_client = OpenAI(base_url=us_base_url,
            api_key=os.environ["PORTKEY_AZURE_US_API_KEY"],
            default_headers=portkey_headers)

# %%
# from pywhyllm.suggesters.tuebingen_model_suggester import TuebingenModelSuggester, Strategy
# modeler = TuebingenModelSuggester(llm= model)

# %%
# from pywhyllm.suggesters.tuebingen_model_suggester_alba import TuebingenModelSuggester, Strategy
# modeler = TuebingenModelSuggester(llm= model)

# %%
from pywhyllm.suggesters.simple_model_suggester import SimpleModelSuggester
modeler= SimpleModelSuggester(llm=model)

# %%
# import re
# import math

# def suggest_pairwise_relationship_with_logprobs_only_answer(self, variable1: str, variable2: str, openai_client=None, model_name="gpt-4o-mini", confidence_level=False):
#     """
#     Suggests a cause-and-effect relationship with detailed log probabilities.
#     Uses OpenAI client directly for full logprob access.
    
#     Args:
#         variable1 (str): The name of the first variable.
#         variable2 (str): The name of the second variable.
#         openai_client: Optional OpenAI client instance. If None, uses guidance model.
#         model_name (str): Model name to use with OpenAI client.
#         confidence_level (bool): Whether to request confidence score from LLM. Default False.
        
#     Returns:
#         dict: Contains 'result', 'description', 'answer', 'confidence_score', 'logprobs', and answer token logprob details.
#     """
#     from openai import OpenAI
    
#     # If no OpenAI client provided, try to create one from environment
#     if openai_client is None:
#         import os
#         # Try to extract connection details from guidance model
#         if hasattr(self.llm, 'engine'):
#             try:
#                 openai_client = OpenAI(
#                     api_key=os.environ.get("OPENAI_API_KEY"),
#                     base_url=os.environ.get("OPENAI_BASE_URL")
#                 )
#             except:
#                 raise ValueError("Could not create OpenAI client. Please pass openai_client parameter.")
    
#     # Construct the prompt based on confidence_level parameter
#     if confidence_level:
#         prompt = f"""Which cause-and-effect-relationship is more likely? Provide reasoning and give your final answer (A, B, or C) in <answer> </answer> tags with the letter only and no whitespaces.

# Additionally, provide your confidence level for this decision as a number between 0 and 1 (where 0 is no confidence and 1 is complete confidence) in <confidence> </confidence> tags.

# A. {variable1} causes {variable2} 
# B. {variable2} causes {variable1} 
# C. neither {variable1} nor {variable2} cause each other."""
#     else:
#         prompt = f"""Which cause-and-effect-relationship is more likely? Provide reasoning and give your final answer (A, B, or C) in <answer> </answer> tags with the letter only and no whitespaces.

# A. {variable1} causes {variable2} 
# B. {variable2} causes {variable1} 
# C. neither {variable1} nor {variable2} cause each other."""
    
#     # Make API call with logprobs
#     response = openai_client.chat.completions.create(
#         model=model_name,
#         messages=[
#             {"role": "system", "content": "You are a helpful assistant for causal reasoning."},
#             {"role": "user", "content": prompt}
#         ],
#         temperature=0.0,
#         logprobs=True,
#         top_logprobs=3,
#         max_tokens=200
#     )
    
#     choice = response.choices[0]
#     description = choice.message.content
#     logprobs_data = []
#     if getattr(choice, "logprobs", None) and getattr(choice.logprobs, "content", None):
#         logprobs_data = choice.logprobs.content

#     # Extract answer
#     answer = re.findall(r"<answer>(.*?)</answer>", description)
#     answer = [ans.strip() for ans in answer]
#     answer_str = "".join(answer) if answer else ""

#     # Extract confidence score only if requested
#     confidence_score = None
#     if confidence_level:
#         confidence_matches = re.findall(r"<confidence>(.*?)</confidence>", description)
#         if confidence_matches:
#             try:
#                 confidence_score = float(confidence_matches[0].strip())
#                 # Ensure confidence is between 0 and 1
#                 confidence_score = max(0.0, min(1.0, confidence_score))
#             except (ValueError, TypeError):
#                 confidence_score = None

#     # Determine result based on the chosen answer
#     if answer_str == "A":
#         result = [variable1, variable2, description]
#     elif answer_str == "B":
#         result = [variable2, variable1, description]
#     elif answer_str == "C":
#         result = [None, None, description]
#     else:
#         result = [None, None, description]

#     answer_token_logprob = None
#     answer_choice_logprobs = {}
#     answer_tokens_logprobs = []

#     if logprobs_data:
#         reconstructed_text = ""
#         token_spans = []
#         for token_item in logprobs_data:
#             token_text = getattr(token_item, "token", "") or ""
#             start_idx = len(reconstructed_text)
#             reconstructed_text += token_text
#             end_idx = len(reconstructed_text)
#             token_spans.append((start_idx, end_idx, token_item))

#         match = re.search(r"<answer>(.*?)</answer>", reconstructed_text, flags=re.DOTALL)
#         if match:
#             content_start, content_end = match.span(1)
#             for start_idx, end_idx, token_item in token_spans:
#                 overlaps_answer = start_idx < content_end and end_idx > content_start
#                 if overlaps_answer:
#                     token_text = getattr(token_item, "token", "") or ""
#                     token_logprob = getattr(token_item, "logprob", None)
#                     answer_tokens_logprobs.append({
#                         "token": token_text,
#                         "logprob": token_logprob
#                     })

#                     token_letter = token_text.strip()
#                     if token_letter in {"A", "B", "C"} and token_logprob is not None:
#                         answer_choice_logprobs[token_letter] = token_logprob

#                     top_alternatives = getattr(token_item, "top_logprobs", None) or []
#                     for alt in top_alternatives:
#                         alt_token = (getattr(alt, "token", "") or "").strip()
#                         if alt_token in {"A", "B", "C"}:
#                             alt_logprob = getattr(alt, "logprob", None)
#                             if alt_logprob is not None:
#                                 answer_choice_logprobs[alt_token] = alt_logprob
#                 if start_idx <= content_start and end_idx > content_start:
#                     if answer_token_logprob is None:
#                         answer_token_logprob = getattr(token_item, "logprob", None)

#     return {
#         'result': result,
#         'description': description,
#         'answer': answer_str,
#         'confidence_score': confidence_score,  # LLM-provided confidence
#         'logprobs': logprobs_data,
#         'answer_token_logprob': answer_token_logprob,
#         'answer_choice_logprobs': answer_choice_logprobs,
#         'answer_tokens_logprobs': answer_tokens_logprobs,
#     }

# %%
# from types import MethodType
# import json

# modeler.suggest_pairwise_relationship_with_logprobs_only_answer = MethodType(
#     suggest_pairwise_relationship_with_logprobs_only_answer, modeler
# )

# result_answer_only = modeler.suggest_pairwise_relationship_with_logprobs_only_answer(
#     "Exercise",
#     "Weight Loss",
#     openai_client=azure_openai_client,
#     confidence_level=True  # Set to True to test confidence functionality
# )

# print("Answer letter:", result_answer_only.get("answer"))
# print("Confidence score:", result_answer_only.get("confidence_score"))
# print("Answer token logprob:", result_answer_only.get("answer_token_logprob"))
# print("A/B/C logprobs:")
# print(json.dumps(result_answer_only.get("answer_choice_logprobs", {}), indent=2))
# print("Tokens within <answer> tags and logprobs:")
# print(json.dumps(result_answer_only.get("answer_tokens_logprobs", []), indent=2))
# Out:
# Answer letter: A
# Confidence score: 0.9
# Answer token logprob: -2.1650272e-05
# A/B/C logprobs:
# {}
# Tokens within <answer> tags and logprobs:
# [
#   {
#     "token": ">A",
#     "logprob": -2.1650272e-05
#   }
# ]

# %%
result_answer_only
# Out:
# {'result': ['Exercise',
#   'Weight Loss',
#   'To determine which cause-and-effect relationship is more likely, we need to analyze the nature of the relationships between exercise and weight loss.\n\nA. Exercise causes Weight Loss: This is a well-established relationship. Regular physical activity increases energy expenditure, which can lead to a caloric deficit and, consequently, weight loss. Numerous studies support this causal link.\n\nB. Weight Loss causes Exercise: While some individuals may feel motivated to exercise after losing weight, this is not a direct causal relationship. Weight loss can lead to increased energy and motivation, but it is not a primary cause of exercise.\n\nC. Neither Exercise nor Weight Loss cause each other: This option suggests that there is no causal relationship between the two, which contradicts the established understanding that exercise can lead to weight loss.\n\nGiven this analysis, the most likely cause-and-effect relationship is that exercise causes weight loss.\n\nTherefore, my final answer is <answer>A</answer> and my confidence level is <confidence>0.9</confidence>.'],
#  'description': 'To determine which cause-and-effect relationship is more likely, we need to analyze the nature of the relationships between exercise and weight loss.\n\nA. Exercise causes Weight Loss: This is a well-established relationship. Regular physical activity increases energy expenditure, which can lead to a caloric deficit and, consequently, weight loss. Numerous studies support this causal link.\n\nB. Weight Loss causes Exercise: While some individuals may feel motivated to exercise after losing weight, this is not a direct causal relationship. Weight loss can lead to increased energy and motivation, but it is not a primary cause of exercise.\n\nC. Neither Exercise nor Weight Loss cause each other: This option suggests that there is no causal relationship between the two, which contradicts the established understanding that exercise can lead to weight loss.\n\nGiven this analysis, the most likely cause-and-effect relationship is that exercise causes weight loss.\n\nTherefore, my final answer is <answer>A</answer> and my confidence level is <confidence>0.9</confidence>.',
#  'answer': 'A',
#  'confidence_score': 0.9,
#  'logprobs': [ChatCompletionTokenLogprob(token='To', bytes=[84, 111], logprob=-0.03740137, top_logprobs=[TopLogprob(token='To', bytes=[84, 111], logprob=-0.03740137), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-4.162401), TopLogprob(token='In', bytes=[73, 110], logprob=-4.787401)]),
#   ChatCompletionTokenLogprob(token=' determine', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101], logprob=-0.436739, top_logprobs=[TopLogprob(token=' determine', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101], logprob=-0.436739), TopLogprob(token=' evaluate', bytes=[32, 101, 118, 97, 108, 117, 97, 116, 101], logprob=-1.436739), TopLogprob(token=' analyze', bytes=[32, 97, 110, 97, 108, 121, 122, 101], logprob=-2.686739)]),
#   ChatCompletionTokenLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.47408468, top_logprobs=[TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.47408468), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.9740847), TopLogprob(token=' a', bytes=[32, 97], logprob=-12.599085)]),
#   ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.016537149, top_logprobs=[TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.016537149), TopLogprob(token=' of', bytes=[32, 111, 102], logprob=-4.391537), TopLogprob(token=' causal', bytes=[32, 99, 97, 117, 115, 97, 108], logprob=-5.641537)]),
#   ChatCompletionTokenLogprob(token='-and', bytes=[45, 97, 110, 100], logprob=-2.6895234e-05, top_logprobs=[TopLogprob(token='-and', bytes=[45, 97, 110, 100], logprob=-2.6895234e-05), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-11.000027), TopLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-11.500027)]),
#   ChatCompletionTokenLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-5.5122365e-07, top_logprobs=[TopLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-5.5122365e-07), TopLogprob(token='-effects', bytes=[45, 101, 102, 102, 101, 99, 116, 115], logprob=-15.000001), TopLogprob(token=' effect', bytes=[32, 101, 102, 102, 101, 99, 116], logprob=-16.75)]),
#   ChatCompletionTokenLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.00037609597, top_logprobs=[TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.00037609597), TopLogprob(token='-', bytes=[45], logprob=-8.000376), TopLogprob(token=' relationships', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112, 115], logprob=-10.875376)]),
#   ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-6.134509e-05, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-6.134509e-05), TopLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-10.250061), TopLogprob(token=' among', bytes=[32, 97, 109, 111, 110, 103], logprob=-10.625061)]),
#   ChatCompletionTokenLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-0.00031079436, top_logprobs=[TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-0.00031079436), TopLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-8.125311), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-11.250311)]),
#   ChatCompletionTokenLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.0002852921, top_logprobs=[TopLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.0002852921), TopLogprob(token=' plausible', bytes=[32, 112, 108, 97, 117, 115, 105, 98, 108, 101], logprob=-8.250285), TopLogprob(token=' probable', bytes=[32, 112, 114, 111, 98, 97, 98, 108, 101], logprob=-10.750285)]),
#   ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.06308303, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.06308303), TopLogprob(token=' among', bytes=[32, 97, 109, 111, 110, 103], logprob=-3.188083), TopLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-3.938083)]),
#   ChatCompletionTokenLogprob(token=' we', bytes=[32, 119, 101], logprob=-0.30041197, top_logprobs=[TopLogprob(token=' we', bytes=[32, 119, 101], logprob=-0.30041197), TopLogprob(token=" let's", bytes=[32, 108, 101, 116, 39, 115], logprob=-1.4254119), TopLogprob(token=' let', bytes=[32, 108, 101, 116], logprob=-4.175412)]),
#   ChatCompletionTokenLogprob(token=' need', bytes=[32, 110, 101, 101, 100], logprob=-0.85951525, top_logprobs=[TopLogprob(token=' need', bytes=[32, 110, 101, 101, 100], logprob=-0.85951525), TopLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-0.98451525), TopLogprob(token=' should', bytes=[32, 115, 104, 111, 117, 108, 100], logprob=-1.8595152)]),
#   ChatCompletionTokenLogprob(token=' to', bytes=[32, 116, 111], logprob=-4.3202e-07, top_logprobs=[TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-4.3202e-07), TopLogprob(token=' a', bytes=[32, 97], logprob=-15.5), TopLogprob(token=' consider', bytes=[32, 99, 111, 110, 115, 105, 100, 101, 114], logprob=-16.625)]),
#   ChatCompletionTokenLogprob(token=' analyze', bytes=[32, 97, 110, 97, 108, 121, 122, 101], logprob=-0.6394863, top_logprobs=[TopLogprob(token=' analyze', bytes=[32, 97, 110, 97, 108, 121, 122, 101], logprob=-0.6394863), TopLogprob(token=' consider', bytes=[32, 99, 111, 110, 115, 105, 100, 101, 114], logprob=-1.0144863), TopLogprob(token=' evaluate', bytes=[32, 101, 118, 97, 108, 117, 97, 116, 101], logprob=-3.0144863)]),
#   ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.28461522, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.28461522), TopLogprob(token=' each', bytes=[32, 101, 97, 99, 104], logprob=-1.4096153), TopLogprob(token=' how', bytes=[32, 104, 111, 119], logprob=-5.784615)]),
#   ChatCompletionTokenLogprob(token=' nature', bytes=[32, 110, 97, 116, 117, 114, 101], logprob=-0.9765907, top_logprobs=[TopLogprob(token=' nature', bytes=[32, 110, 97, 116, 117, 114, 101], logprob=-0.9765907), TopLogprob(token=' relationships', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112, 115], logprob=-1.4765906), TopLogprob(token=' connections', bytes=[32, 99, 111, 110, 110, 101, 99, 116, 105, 111, 110, 115], logprob=-1.9765906)]),
#   ChatCompletionTokenLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.000646791, top_logprobs=[TopLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.000646791), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-7.6256466), TopLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-8.750647)]),
#   ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.0934836, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.0934836), TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-3.0934837), TopLogprob(token=' both', bytes=[32, 98, 111, 116, 104], logprob=-3.8434837)]),
#   ChatCompletionTokenLogprob(token=' relationships', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112, 115], logprob=-0.4810173, top_logprobs=[TopLogprob(token=' relationships', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112, 115], logprob=-0.4810173), TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-1.3560174), TopLogprob(token=' two', bytes=[32, 116, 119, 111], logprob=-2.8560174)]),
#   ChatCompletionTokenLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-0.33422926, top_logprobs=[TopLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-0.33422926), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-2.4592292), TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-2.8342292)]),
#   ChatCompletionTokenLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-0.0050859875, top_logprobs=[TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-0.0050859875), TopLogprob(token=' "', bytes=[32, 34], logprob=-6.005086), TopLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=-6.255086)]),
#   ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-1.0280384e-06, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-1.0280384e-06), TopLogprob(token=',', bytes=[44], logprob=-14.125001), TopLogprob(token=' (', bytes=[32, 40], logprob=-15.500001)]),
#   ChatCompletionTokenLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=0.0, top_logprobs=[TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=0.0), TopLogprob(token=' body', bytes=[32, 98, 111, 100, 121], logprob=-17.0), TopLogprob(token=' weigh', bytes=[32, 119, 101, 105, 103, 104], logprob=-19.5)]),
#   ChatCompletionTokenLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-2.4584822e-06, top_logprobs=[TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-2.4584822e-06), TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-13.375003), TopLogprob(token='.', bytes=[46], logprob=-14.500003)]),
#   ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.10656351, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.10656351), TopLogprob(token='.', bytes=[46], logprob=-2.6065636), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-3.6065636)]),
#   ChatCompletionTokenLogprob(token='A', bytes=[65], logprob=-0.041882697, top_logprobs=[TopLogprob(token='A', bytes=[65], logprob=-0.041882697), TopLogprob(token='1', bytes=[49], logprob=-3.9168828), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-4.6668825)]),
#   ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-0.007976503, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-0.007976503), TopLogprob(token=':', bytes=[58], logprob=-4.8829765), TopLogprob(token=')', bytes=[41], logprob=-8.382977)]),
#   ChatCompletionTokenLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=-0.16438533, top_logprobs=[TopLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=-0.16438533), TopLogprob(token=' **', bytes=[32, 42, 42], logprob=-2.4143853), TopLogprob(token=' "', bytes=[32, 34], logprob=-2.7893853)]),
#   ChatCompletionTokenLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-0.006143392, top_logprobs=[TopLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-0.006143392), TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-6.3811436), TopLogprob(token=' causing', bytes=[32, 99, 97, 117, 115, 105, 110, 103], logprob=-6.7561436)]),
#   ChatCompletionTokenLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=-0.22541966, top_logprobs=[TopLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=-0.22541966), TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-1.6004196), TopLogprob(token='Weight', bytes=[87, 101, 105, 103, 104, 116], logprob=-12.60042)]),
#   ChatCompletionTokenLogprob(token=' Loss', bytes=[32, 76, 111, 115, 115], logprob=-4.365741e-06, top_logprobs=[TopLogprob(token=' Loss', bytes=[32, 76, 111, 115, 115], logprob=-4.365741e-06), TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-12.375005), TopLogprob(token=' Lost', bytes=[32, 76, 111, 115, 116], logprob=-16.000004)]),
#   ChatCompletionTokenLogprob(token=':', bytes=[58], logprob=-0.10037748, top_logprobs=[TopLogprob(token=':', bytes=[58], logprob=-0.10037748), TopLogprob(token=' -', bytes=[32, 45], logprob=-3.1003776), TopLogprob(token=':\n', bytes=[58, 10], logprob=-3.1003776)]),
#   ChatCompletionTokenLogprob(token=' This', bytes=[32, 84, 104, 105, 115], logprob=-0.018929176, top_logprobs=[TopLogprob(token=' This', bytes=[32, 84, 104, 105, 115], logprob=-0.018929176), TopLogprob(token=' There', bytes=[32, 84, 104, 101, 114, 101], logprob=-5.018929), TopLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=-5.768929)]),
#   ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.49882737, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.49882737), TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-1.2488273), TopLogprob(token=' statement', bytes=[32, 115, 116, 97, 116, 101, 109, 101, 110, 116], logprob=-2.3738275)]),
#   ChatCompletionTokenLogprob(token=' a', bytes=[32, 97], logprob=-0.08266985, top_logprobs=[TopLogprob(token=' a', bytes=[32, 97], logprob=-0.08266985), TopLogprob(token=' widely', bytes=[32, 119, 105, 100, 101, 108, 121], logprob=-3.5826697), TopLogprob(token=' supported', bytes=[32, 115, 117, 112, 112, 111, 114, 116, 101, 100], logprob=-3.9576697)]),
#   ChatCompletionTokenLogprob(token=' well', bytes=[32, 119, 101, 108, 108], logprob=-0.37011206, top_logprobs=[TopLogprob(token=' well', bytes=[32, 119, 101, 108, 108], logprob=-0.37011206), TopLogprob(token=' widely', bytes=[32, 119, 105, 100, 101, 108, 121], logprob=-1.3701121), TopLogprob(token=' commonly', bytes=[32, 99, 111, 109, 109, 111, 110, 108, 121], logprob=-3.120112)]),
#   ChatCompletionTokenLogprob(token='-established', bytes=[45, 101, 115, 116, 97, 98, 108, 105, 115, 104, 101, 100], logprob=-0.7934774, top_logprobs=[TopLogprob(token='-established', bytes=[45, 101, 115, 116, 97, 98, 108, 105, 115, 104, 101, 100], logprob=-0.7934774), TopLogprob(token='-supported', bytes=[45, 115, 117, 112, 112, 111, 114, 116, 101, 100], logprob=-0.7934774), TopLogprob(token='-d', bytes=[45, 100], logprob=-2.4184775)]),
#   ChatCompletionTokenLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.17701939, top_logprobs=[TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.17701939), TopLogprob(token=' causal', bytes=[32, 99, 97, 117, 115, 97, 108], logprob=-2.3020194), TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-3.6770194)]),
#   ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-0.56358963, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-0.56358963), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-1.3135896), TopLogprob(token=' supported', bytes=[32, 115, 117, 112, 112, 111, 114, 116, 101, 100], logprob=-2.3135896)]),
#   ChatCompletionTokenLogprob(token=' Regular', bytes=[32, 82, 101, 103, 117, 108, 97, 114], logprob=-0.41502357, top_logprobs=[TopLogprob(token=' Regular', bytes=[32, 82, 101, 103, 117, 108, 97, 114], logprob=-0.41502357), TopLogprob(token=' Eng', bytes=[32, 69, 110, 103], logprob=-1.1650236), TopLogprob(token=' When', bytes=[32, 87, 104, 101, 110], logprob=-4.790024)]),
#   ChatCompletionTokenLogprob(token=' physical', bytes=[32, 112, 104, 121, 115, 105, 99, 97, 108], logprob=-0.22566035, top_logprobs=[TopLogprob(token=' physical', bytes=[32, 112, 104, 121, 115, 105, 99, 97, 108], logprob=-0.22566035), TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-1.6006603), TopLogprob(token=' aerobic', bytes=[32, 97, 101, 114, 111, 98, 105, 99], logprob=-9.22566)]),
#   ChatCompletionTokenLogprob(token=' activity', bytes=[32, 97, 99, 116, 105, 118, 105, 116, 121], logprob=-0.0046516727, top_logprobs=[TopLogprob(token=' activity', bytes=[32, 97, 99, 116, 105, 118, 105, 116, 121], logprob=-0.0046516727), TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-5.3796515), TopLogprob(token=' activities', bytes=[32, 97, 99, 116, 105, 118, 105, 116, 105, 101, 115], logprob=-10.504652)]),
#   ChatCompletionTokenLogprob(token=' increases', bytes=[32, 105, 110, 99, 114, 101, 97, 115, 101, 115], logprob=-1.702273, top_logprobs=[TopLogprob(token=' increases', bytes=[32, 105, 110, 99, 114, 101, 97, 115, 101, 115], logprob=-1.702273), TopLogprob(token=' burns', bytes=[32, 98, 117, 114, 110, 115], logprob=-1.702273), TopLogprob(token=' helps', bytes=[32, 104, 101, 108, 112, 115], logprob=-1.827273)]),
#   ChatCompletionTokenLogprob(token=' energy', bytes=[32, 101, 110, 101, 114, 103, 121], logprob=-0.70787084, top_logprobs=[TopLogprob(token=' energy', bytes=[32, 101, 110, 101, 114, 103, 121], logprob=-0.70787084), TopLogprob(token=' calorie', bytes=[32, 99, 97, 108, 111, 114, 105, 101], logprob=-1.0828708), TopLogprob(token=' calor', bytes=[32, 99, 97, 108, 111, 114], logprob=-2.332871)]),
#   ChatCompletionTokenLogprob(token=' expenditure', bytes=[32, 101, 120, 112, 101, 110, 100, 105, 116, 117, 114, 101], logprob=-3.655073e-05, top_logprobs=[TopLogprob(token=' expenditure', bytes=[32, 101, 120, 112, 101, 110, 100, 105, 116, 117, 114, 101], logprob=-3.655073e-05), TopLogprob(token=' expenditures', bytes=[32, 101, 120, 112, 101, 110, 100, 105, 116, 117, 114, 101, 115], logprob=-10.750036), TopLogprob(token=' consumption', bytes=[32, 99, 111, 110, 115, 117, 109, 112, 116, 105, 111, 110], logprob=-11.625036)]),
#   ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.31732145, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.31732145), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-1.3173214), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-5.5673213)]),
#   ChatCompletionTokenLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.10948278, top_logprobs=[TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.10948278), TopLogprob(token=' leading', bytes=[32, 108, 101, 97, 100, 105, 110, 103], logprob=-3.7344828), TopLogprob(token=' helps', bytes=[32, 104, 101, 108, 112, 115], logprob=-4.109483)]),
#   ChatCompletionTokenLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-0.062389664, top_logprobs=[TopLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-0.062389664), TopLogprob(token=',', bytes=[44], logprob=-3.1873896), TopLogprob(token=' contributes', bytes=[32, 99, 111, 110, 116, 114, 105, 98, 117, 116, 101, 115], logprob=-4.93739)]),
#   ChatCompletionTokenLogprob(token=' lead', bytes=[32, 108, 101, 97, 100], logprob=-0.08309889, top_logprobs=[TopLogprob(token=' lead', bytes=[32, 108, 101, 97, 100], logprob=-0.08309889), TopLogprob(token=' contribute', bytes=[32, 99, 111, 110, 116, 114, 105, 98, 117, 116, 101], logprob=-2.833099), TopLogprob(token=' help', bytes=[32, 104, 101, 108, 112], logprob=-4.583099)]),
#   ChatCompletionTokenLogprob(token=' to', bytes=[32, 116, 111], logprob=-2.2484697e-05, top_logprobs=[TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-2.2484697e-05), TopLogprob(token=' directly', bytes=[32, 100, 105, 114, 101, 99, 116, 108, 121], logprob=-11.250023), TopLogprob(token=' individuals', bytes=[32, 105, 110, 100, 105, 118, 105, 100, 117, 97, 108, 115], logprob=-12.125023)]),
#   ChatCompletionTokenLogprob(token=' a', bytes=[32, 97], logprob=-0.40453148, top_logprobs=[TopLogprob(token=' a', bytes=[32, 97], logprob=-0.40453148), TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-1.1545315), TopLogprob(token=' calorie', bytes=[32, 99, 97, 108, 111, 114, 105, 101], logprob=-4.9045315)]),
#   ChatCompletionTokenLogprob(token=' calor', bytes=[32, 99, 97, 108, 111, 114], logprob=-0.69884855, top_logprobs=[TopLogprob(token=' calor', bytes=[32, 99, 97, 108, 111, 114], logprob=-0.69884855), TopLogprob(token=' calorie', bytes=[32, 99, 97, 108, 111, 114, 105, 101], logprob=-0.69884855), TopLogprob(token=' negative', bytes=[32, 110, 101, 103, 97, 116, 105, 118, 101], logprob=-5.5738487)]),
#   ChatCompletionTokenLogprob(token='ic', bytes=[105, 99], logprob=-2.618001e-05, top_logprobs=[TopLogprob(token='ic', bytes=[105, 99], logprob=-2.618001e-05), TopLogprob(token='ific', bytes=[105, 102, 105, 99], logprob=-10.625026), TopLogprob(token='ically', bytes=[105, 99, 97, 108, 108, 121], logprob=-13.375026)]),
#   ChatCompletionTokenLogprob(token=' deficit', bytes=[32, 100, 101, 102, 105, 99, 105, 116], logprob=-1.0683535e-05, top_logprobs=[TopLogprob(token=' deficit', bytes=[32, 100, 101, 102, 105, 99, 105, 116], logprob=-1.0683535e-05), TopLogprob(token=' deficiency', bytes=[32, 100, 101, 102, 105, 99, 105, 101, 110, 99, 121], logprob=-11.5000105), TopLogprob(token=' def', bytes=[32, 100, 101, 102], logprob=-15.5000105)]),
#   ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.41323295, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.41323295), TopLogprob(token=' when', bytes=[32, 119, 104, 101, 110], logprob=-2.038233), TopLogprob(token=' if', bytes=[32, 105, 102], logprob=-2.288233)]),
#   ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-1.3115997, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-1.3115997), TopLogprob(token=' ultimately', bytes=[32, 117, 108, 116, 105, 109, 97, 116, 101, 108, 121], logprob=-1.8115997), TopLogprob(token=' subsequently', bytes=[32, 115, 117, 98, 115, 101, 113, 117, 101, 110, 116, 108, 121], logprob=-2.0615997)]),
#   ChatCompletionTokenLogprob(token=' consequently', bytes=[32, 99, 111, 110, 115, 101, 113, 117, 101, 110, 116, 108, 121], logprob=-0.3304835, top_logprobs=[TopLogprob(token=' consequently', bytes=[32, 99, 111, 110, 115, 101, 113, 117, 101, 110, 116, 108, 121], logprob=-0.3304835), TopLogprob(token=' subsequently', bytes=[32, 115, 117, 98, 115, 101, 113, 117, 101, 110, 116, 108, 121], logprob=-1.9554834), TopLogprob(token=' ultimately', bytes=[32, 117, 108, 116, 105, 109, 97, 116, 101, 108, 121], logprob=-2.4554834)]),
#   ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-1.9361265e-07, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-1.9361265e-07), TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-16.75), TopLogprob(token=' over', bytes=[32, 111, 118, 101, 114], logprob=-18.5)]),
#   ChatCompletionTokenLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-0.0006053375, top_logprobs=[TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-0.0006053375), TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-7.875605), TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-9.125606)]),
#   ChatCompletionTokenLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-3.1737043e-06, top_logprobs=[TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-3.1737043e-06), TopLogprob(token=' reduction', bytes=[32, 114, 101, 100, 117, 99, 116, 105, 111, 110], logprob=-12.750003), TopLogprob(token=' lost', bytes=[32, 108, 111, 115, 116], logprob=-16.375004)]),
#   ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-0.6617841, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-0.6617841), TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.9117841), TopLogprob(token=' if', bytes=[32, 105, 102], logprob=-3.6617842)]),
#   ChatCompletionTokenLogprob(token=' Numerous', bytes=[32, 78, 117, 109, 101, 114, 111, 117, 115], logprob=-0.6246408, top_logprobs=[TopLogprob(token=' Numerous', bytes=[32, 78, 117, 109, 101, 114, 111, 117, 115], logprob=-0.6246408), TopLogprob(token=' Many', bytes=[32, 77, 97, 110, 121], logprob=-1.3746408), TopLogprob(token=' This', bytes=[32, 84, 104, 105, 115], logprob=-3.124641)]),
#   ChatCompletionTokenLogprob(token=' studies', bytes=[32, 115, 116, 117, 100, 105, 101, 115], logprob=-0.014514035, top_logprobs=[TopLogprob(token=' studies', bytes=[32, 115, 116, 117, 100, 105, 101, 115], logprob=-0.014514035), TopLogprob(token=' scientific', bytes=[32, 115, 99, 105, 101, 110, 116, 105, 102, 105, 99], logprob=-4.264514), TopLogprob(token=' research', bytes=[32, 114, 101, 115, 101, 97, 114, 99, 104], logprob=-8.764514)]),
#   ChatCompletionTokenLogprob(token=' support', bytes=[32, 115, 117, 112, 112, 111, 114, 116], logprob=-0.22593237, top_logprobs=[TopLogprob(token=' support', bytes=[32, 115, 117, 112, 112, 111, 114, 116], logprob=-0.22593237), TopLogprob(token=' have', bytes=[32, 104, 97, 118, 101], logprob=-1.9759324), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-3.1009324)]),
#   ChatCompletionTokenLogprob(token=' this', bytes=[32, 116, 104, 105, 115], logprob=-0.6711602, top_logprobs=[TopLogprob(token=' this', bytes=[32, 116, 104, 105, 115], logprob=-0.6711602), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.7961602), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-3.2961602)]),
#   ChatCompletionTokenLogprob(token=' causal', bytes=[32, 99, 97, 117, 115, 97, 108], logprob=-0.6613239, top_logprobs=[TopLogprob(token=' causal', bytes=[32, 99, 97, 117, 115, 97, 108], logprob=-0.6613239), TopLogprob(token=' claim', bytes=[32, 99, 108, 97, 105, 109], logprob=-2.036324), TopLogprob(token=' connection', bytes=[32, 99, 111, 110, 110, 101, 99, 116, 105, 111, 110], logprob=-2.536324)]),
#   ChatCompletionTokenLogprob(token=' link', bytes=[32, 108, 105, 110, 107], logprob=-0.6808488, top_logprobs=[TopLogprob(token=' link', bytes=[32, 108, 105, 110, 107], logprob=-0.6808488), TopLogprob(token=' direction', bytes=[32, 100, 105, 114, 101, 99, 116, 105, 111, 110], logprob=-1.1808488), TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-2.1808488)]),
#   ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.24152005, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.24152005), TopLogprob(token=',', bytes=[44], logprob=-1.61652), TopLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-4.61652)]),
#   ChatCompletionTokenLogprob(token='B', bytes=[66], logprob=0.0, top_logprobs=[TopLogprob(token='B', bytes=[66], logprob=0.0), TopLogprob(token=' B', bytes=[32, 66], logprob=-20.625), TopLogprob(token='C', bytes=[67], logprob=-24.25)]),
#   ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-1.9361265e-07, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-1.9361265e-07), TopLogprob(token=':', bytes=[58], logprob=-15.75), TopLogprob(token='.W', bytes=[46, 87], logprob=-20.25)]),
#   ChatCompletionTokenLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=0.0, top_logprobs=[TopLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=0.0), TopLogprob(token='Weight', bytes=[87, 101, 105, 103, 104, 116], logprob=-21.25), TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-21.625)]),
#   ChatCompletionTokenLogprob(token=' Loss', bytes=[32, 76, 111, 115, 115], logprob=-4.365741e-06, top_logprobs=[TopLogprob(token=' Loss', bytes=[32, 76, 111, 115, 115], logprob=-4.365741e-06), TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-12.375005), TopLogprob(token=' Lost', bytes=[32, 76, 111, 115, 116], logprob=-16.500004)]),
#   ChatCompletionTokenLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-2.3392786e-06, top_logprobs=[TopLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-2.3392786e-06), TopLogprob(token=' Causes', bytes=[32, 67, 97, 117, 115, 101, 115], logprob=-13.500002), TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-14.875002)]),
#   ChatCompletionTokenLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=0.0, top_logprobs=[TopLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=0.0), TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-18.25), TopLogprob(token='Exercise', bytes=[69, 120, 101, 114, 99, 105, 115, 101], logprob=-19.125)]),
#   ChatCompletionTokenLogprob(token=':', bytes=[58], logprob=0.0, top_logprobs=[TopLogprob(token=':', bytes=[58], logprob=0.0), TopLogprob(token='.', bytes=[46], logprob=-18.625), TopLogprob(token=':\n', bytes=[58, 10], logprob=-19.125)]),
#   ChatCompletionTokenLogprob(token=' While', bytes=[32, 87, 104, 105, 108, 101], logprob=-0.07267933, top_logprobs=[TopLogprob(token=' While', bytes=[32, 87, 104, 105, 108, 101], logprob=-0.07267933), TopLogprob(token=' This', bytes=[32, 84, 104, 105, 115], logprob=-2.6976793), TopLogprob(token=' Although', bytes=[32, 65, 108, 116, 104, 111, 117, 103, 104], logprob=-6.4476795)]),
#   ChatCompletionTokenLogprob(token=' some', bytes=[32, 115, 111, 109, 101], logprob=-1.0095013, top_logprobs=[TopLogprob(token=' some', bytes=[32, 115, 111, 109, 101], logprob=-1.0095013), TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-1.8845013), TopLogprob(token=' losing', bytes=[32, 108, 111, 115, 105, 110, 103], logprob=-1.8845013)]),
#   ChatCompletionTokenLogprob(token=' individuals', bytes=[32, 105, 110, 100, 105, 118, 105, 100, 117, 97, 108, 115], logprob=-0.12818226, top_logprobs=[TopLogprob(token=' individuals', bytes=[32, 105, 110, 100, 105, 118, 105, 100, 117, 97, 108, 115], logprob=-0.12818226), TopLogprob(token=' people', bytes=[32, 112, 101, 111, 112, 108, 101], logprob=-2.3781822), TopLogprob(token=' may', bytes=[32, 109, 97, 121], logprob=-4.1281824)]),
#   ChatCompletionTokenLogprob(token=' may', bytes=[32, 109, 97, 121], logprob=-0.08692657, top_logprobs=[TopLogprob(token=' may', bytes=[32, 109, 97, 121], logprob=-0.08692657), TopLogprob(token=' might', bytes=[32, 109, 105, 103, 104, 116], logprob=-2.9619265), TopLogprob(token=' who', bytes=[32, 119, 104, 111], logprob=-3.4619265)]),
#   ChatCompletionTokenLogprob(token=' feel', bytes=[32, 102, 101, 101, 108], logprob=-0.5350056, top_logprobs=[TopLogprob(token=' feel', bytes=[32, 102, 101, 101, 108], logprob=-0.5350056), TopLogprob(token=' be', bytes=[32, 98, 101], logprob=-1.5350056), TopLogprob(token=' become', bytes=[32, 98, 101, 99, 111, 109, 101], logprob=-2.7850056)]),
#   ChatCompletionTokenLogprob(token=' motivated', bytes=[32, 109, 111, 116, 105, 118, 97, 116, 101, 100], logprob=-0.18529522, top_logprobs=[TopLogprob(token=' motivated', bytes=[32, 109, 111, 116, 105, 118, 97, 116, 101, 100], logprob=-0.18529522), TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.9352952), TopLogprob(token=' encouraged', bytes=[32, 101, 110, 99, 111, 117, 114, 97, 103, 101, 100], logprob=-3.810295)]),
#   ChatCompletionTokenLogprob(token=' to', bytes=[32, 116, 111], logprob=-4.365741e-06, top_logprobs=[TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-4.365741e-06), TopLogprob(token=' or', bytes=[32, 111, 114], logprob=-12.500005), TopLogprob(token=' by', bytes=[32, 98, 121], logprob=-14.625005)]),
#   ChatCompletionTokenLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-0.015510679, top_logprobs=[TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-0.015510679), TopLogprob(token=' start', bytes=[32, 115, 116, 97, 114, 116], logprob=-4.8905106), TopLogprob(token=' engage', bytes=[32, 101, 110, 103, 97, 103, 101], logprob=-5.0155106)]),
#   ChatCompletionTokenLogprob(token=' after', bytes=[32, 97, 102, 116, 101, 114], logprob=-0.63858443, top_logprobs=[TopLogprob(token=' after', bytes=[32, 97, 102, 116, 101, 114], logprob=-0.63858443), TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.2635844), TopLogprob(token=' as', bytes=[32, 97, 115], logprob=-1.8885844)]),
#   ChatCompletionTokenLogprob(token=' losing', bytes=[32, 108, 111, 115, 105, 110, 103], logprob=-0.29512382, top_logprobs=[TopLogprob(token=' losing', bytes=[32, 108, 111, 115, 105, 110, 103], logprob=-0.29512382), TopLogprob(token=' experiencing', bytes=[32, 101, 120, 112, 101, 114, 105, 101, 110, 99, 105, 110, 103], logprob=-1.6701238), TopLogprob(token=' achieving', bytes=[32, 97, 99, 104, 105, 101, 118, 105, 110, 103], logprob=-3.2951238)]),
#   ChatCompletionTokenLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-0.0002667, top_logprobs=[TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-0.0002667), TopLogprob(token=' some', bytes=[32, 115, 111, 109, 101], logprob=-8.250267), TopLogprob(token=' a', bytes=[32, 97], logprob=-12.250267)]),
#   ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.0324422, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.0324422), TopLogprob(token=' (', bytes=[32, 40], logprob=-4.407442), TopLogprob(token=' or', bytes=[32, 111, 114], logprob=-4.657442)]),
#   ChatCompletionTokenLogprob(token=' this', bytes=[32, 116, 104, 105, 115], logprob=-0.31223428, top_logprobs=[TopLogprob(token=' this', bytes=[32, 116, 104, 105, 115], logprob=-0.31223428), TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-1.8122343), TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-2.8122344)]),
#   ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.18731579, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.18731579), TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-2.0623157), TopLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-3.5623157)]),
#   ChatCompletionTokenLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-0.79525745, top_logprobs=[TopLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-0.79525745), TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-0.92025745), TopLogprob(token=' generally', bytes=[32, 103, 101, 110, 101, 114, 97, 108, 108, 121], logprob=-2.4202576)]),
#   ChatCompletionTokenLogprob(token=' a', bytes=[32, 97], logprob=-0.030454349, top_logprobs=[TopLogprob(token=' a', bytes=[32, 97], logprob=-0.030454349), TopLogprob(token=' generally', bytes=[32, 103, 101, 110, 101, 114, 97, 108, 108, 121], logprob=-5.030454), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-5.280454)]),
#   ChatCompletionTokenLogprob(token=' direct', bytes=[32, 100, 105, 114, 101, 99, 116], logprob=-0.4487545, top_logprobs=[TopLogprob(token=' direct', bytes=[32, 100, 105, 114, 101, 99, 116], logprob=-0.4487545), TopLogprob(token=' general', bytes=[32, 103, 101, 110, 101, 114, 97, 108], logprob=-2.6987545), TopLogprob(token=' universal', bytes=[32, 117, 110, 105, 118, 101, 114, 115, 97, 108], logprob=-2.6987545)]),
#   ChatCompletionTokenLogprob(token=' causal', bytes=[32, 99, 97, 117, 115, 97, 108], logprob=-0.38894877, top_logprobs=[TopLogprob(token=' causal', bytes=[32, 99, 97, 117, 115, 97, 108], logprob=-0.38894877), TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-1.3889488), TopLogprob(token=' or', bytes=[32, 111, 114], logprob=-3.2639487)]),
#   ChatCompletionTokenLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.011408189, top_logprobs=[TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.011408189), TopLogprob(token=' link', bytes=[32, 108, 105, 110, 107], logprob=-5.2614083), TopLogprob(token=' effect', bytes=[32, 101, 102, 102, 101, 99, 116], logprob=-5.3864083)]),
#   ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-0.03294707, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-0.03294707), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-4.657947), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-4.907947)]),
#   ChatCompletionTokenLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=-0.23668437, top_logprobs=[TopLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=-0.23668437), TopLogprob(token=' Instead', bytes=[32, 73, 110, 115, 116, 101, 97, 100], logprob=-2.7366843), TopLogprob(token=' Rather', bytes=[32, 82, 97, 116, 104, 101, 114], logprob=-2.8616843)]),
#   ChatCompletionTokenLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-0.00010854974, top_logprobs=[TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-0.00010854974), TopLogprob(token=' reduction', bytes=[32, 114, 101, 100, 117, 99, 116, 105, 111, 110], logprob=-10.500109), TopLogprob(token=' itself', bytes=[32, 105, 116, 115, 101, 108, 102], logprob=-10.875109)]),
#   ChatCompletionTokenLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-1.2890071, top_logprobs=[TopLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-1.2890071), TopLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-1.6640071), TopLogprob(token=' itself', bytes=[32, 105, 116, 115, 101, 108, 102], logprob=-1.9140071)]),
#   ChatCompletionTokenLogprob(token=' lead', bytes=[32, 108, 101, 97, 100], logprob=-1.3169831, top_logprobs=[TopLogprob(token=' lead', bytes=[32, 108, 101, 97, 100], logprob=-1.3169831), TopLogprob(token=' be', bytes=[32, 98, 101], logprob=-1.6919831), TopLogprob(token=' result', bytes=[32, 114, 101, 115, 117, 108, 116], logprob=-1.8169831)]),
#   ChatCompletionTokenLogprob(token=' to', bytes=[32, 116, 111], logprob=-0.0009574358, top_logprobs=[TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-0.0009574358), TopLogprob(token=' some', bytes=[32, 115, 111, 109, 101], logprob=-7.7509575), TopLogprob(token=' people', bytes=[32, 112, 101, 111, 112, 108, 101], logprob=-8.1259575)]),
#   ChatCompletionTokenLogprob(token=' increased', bytes=[32, 105, 110, 99, 114, 101, 97, 115, 101, 100], logprob=-0.33507028, top_logprobs=[TopLogprob(token=' increased', bytes=[32, 105, 110, 99, 114, 101, 97, 115, 101, 100], logprob=-0.33507028), TopLogprob(token=' improved', bytes=[32, 105, 109, 112, 114, 111, 118, 101, 100], logprob=-1.9600703), TopLogprob(token=' an', bytes=[32, 97, 110], logprob=-3.4600704)]),
#   ChatCompletionTokenLogprob(token=' energy', bytes=[32, 101, 110, 101, 114, 103, 121], logprob=-0.70210266, top_logprobs=[TopLogprob(token=' energy', bytes=[32, 101, 110, 101, 114, 103, 121], logprob=-0.70210266), TopLogprob(token=' physical', bytes=[32, 112, 104, 121, 115, 105, 99, 97, 108], logprob=-1.5771027), TopLogprob(token=' motivation', bytes=[32, 109, 111, 116, 105, 118, 97, 116, 105, 111, 110], logprob=-2.2021027)]),
#   ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.2474414, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.2474414), TopLogprob(token=' levels', bytes=[32, 108, 101, 118, 101, 108, 115], logprob=-1.6224414), TopLogprob(token=' or', bytes=[32, 111, 114], logprob=-4.1224413)]),
#   ChatCompletionTokenLogprob(token=' motivation', bytes=[32, 109, 111, 116, 105, 118, 97, 116, 105, 111, 110], logprob=-0.54881406, top_logprobs=[TopLogprob(token=' motivation', bytes=[32, 109, 111, 116, 105, 118, 97, 116, 105, 111, 110], logprob=-0.54881406), TopLogprob(token=' willingness', bytes=[32, 119, 105, 108, 108, 105, 110, 103, 110, 101, 115, 115], logprob=-2.423814), TopLogprob(token=' confidence', bytes=[32, 99, 111, 110, 102, 105, 100, 101, 110, 99, 101], logprob=-2.923814)]),
#   ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-1.0380665, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-1.0380665), TopLogprob(token=' for', bytes=[32, 102, 111, 114], logprob=-1.1630665), TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-1.1630665)]),
#   ChatCompletionTokenLogprob(token=' but', bytes=[32, 98, 117, 116], logprob=-0.09212327, top_logprobs=[TopLogprob(token=' but', bytes=[32, 98, 117, 116], logprob=-0.09212327), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-2.8421233), TopLogprob(token=' potentially', bytes=[32, 112, 111, 116, 101, 110, 116, 105, 97, 108, 108, 121], logprob=-4.217123)]),
#   ChatCompletionTokenLogprob(token=' it', bytes=[32, 105, 116], logprob=-0.091526665, top_logprobs=[TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-0.091526665), TopLogprob(token=" it's", bytes=[32, 105, 116, 39, 115], logprob=-3.5915267), TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-3.7165267)]),
#   ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.8123314, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.8123314), TopLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-0.9373314), TopLogprob(token=" doesn't", bytes=[32, 100, 111, 101, 115, 110, 39, 116], logprob=-2.4373314)]),
#   ChatCompletionTokenLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-0.5026162, top_logprobs=[TopLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-0.5026162), TopLogprob(token=' typically', bytes=[32, 116, 121, 112, 105, 99, 97, 108, 108, 121], logprob=-2.0026162), TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-2.3776162)]),
#   ChatCompletionTokenLogprob(token=' a', bytes=[32, 97], logprob=-0.5780559, top_logprobs=[TopLogprob(token=' a', bytes=[32, 97], logprob=-0.5780559), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-1.4530559), TopLogprob(token=' inherently', bytes=[32, 105, 110, 104, 101, 114, 101, 110, 116, 108, 121], logprob=-2.9530559)]),
#   ChatCompletionTokenLogprob(token=' primary', bytes=[32, 112, 114, 105, 109, 97, 114, 121], logprob=-0.6345007, top_logprobs=[TopLogprob(token=' primary', bytes=[32, 112, 114, 105, 109, 97, 114, 121], logprob=-0.6345007), TopLogprob(token=' consistent', bytes=[32, 99, 111, 110, 115, 105, 115, 116, 101, 110, 116], logprob=-2.1345007), TopLogprob(token=' reliable', bytes=[32, 114, 101, 108, 105, 97, 98, 108, 101], logprob=-2.7595007)]),
#   ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.34765673, top_logprobs=[TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.34765673), TopLogprob(token=' driver', bytes=[32, 100, 114, 105, 118, 101, 114], logprob=-1.3476567), TopLogprob(token=' factor', bytes=[32, 102, 97, 99, 116, 111, 114], logprob=-3.9726567)]),
#   ChatCompletionTokenLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.024037298, top_logprobs=[TopLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.024037298), TopLogprob(token=' for', bytes=[32, 102, 111, 114], logprob=-4.0240374), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-5.3990374)]),
#   ChatCompletionTokenLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-0.35109627, top_logprobs=[TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-0.35109627), TopLogprob(token=' exercising', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 105, 110, 103], logprob=-2.1010962), TopLogprob(token=' engaging', bytes=[32, 101, 110, 103, 97, 103, 105, 110, 103], logprob=-2.9760962)]),
#   ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.8659689, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.8659689), TopLogprob(token=' itself', bytes=[32, 105, 116, 115, 101, 108, 102], logprob=-1.740969), TopLogprob(token='.', bytes=[46], logprob=-1.865969)]),
#   ChatCompletionTokenLogprob(token='C', bytes=[67], logprob=0.0, top_logprobs=[TopLogprob(token='C', bytes=[67], logprob=0.0), TopLogprob(token=' C', bytes=[32, 67], logprob=-22.5), TopLogprob(token='D', bytes=[68], logprob=-23.75)]),
#   ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-1.0206721e-05, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-1.0206721e-05), TopLogprob(token=':', bytes=[58], logprob=-11.5000105), TopLogprob(token=',', bytes=[44], logprob=-18.37501)]),
#   ChatCompletionTokenLogprob(token=' Neither', bytes=[32, 78, 101, 105, 116, 104, 101, 114], logprob=-0.16025561, top_logprobs=[TopLogprob(token=' Neither', bytes=[32, 78, 101, 105, 116, 104, 101, 114], logprob=-0.16025561), TopLogprob(token=' neither', bytes=[32, 110, 101, 105, 116, 104, 101, 114], logprob=-1.9102557), TopLogprob(token=' Ne', bytes=[32, 78, 101], logprob=-11.785255)]),
#   ChatCompletionTokenLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=-0.00044592362, top_logprobs=[TopLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=-0.00044592362), TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-7.750446), TopLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-11.250446)]),
#   ChatCompletionTokenLogprob(token=' nor', bytes=[32, 110, 111, 114], logprob=-5.1928004e-05, top_logprobs=[TopLogprob(token=' nor', bytes=[32, 110, 111, 114], logprob=-5.1928004e-05), TopLogprob(token=' Nor', bytes=[32, 78, 111, 114], logprob=-9.8750515), TopLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-16.125051)]),
#   ChatCompletionTokenLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=-1.9361265e-07, top_logprobs=[TopLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=-1.9361265e-07), TopLogprob(token=' We', bytes=[32, 87, 101], logprob=-16.75), TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-18.125)]),
#   ChatCompletionTokenLogprob(token=' Loss', bytes=[32, 76, 111, 115, 115], logprob=-7.89631e-07, top_logprobs=[TopLogprob(token=' Loss', bytes=[32, 76, 111, 115, 115], logprob=-7.89631e-07), TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-14.125001), TopLogprob(token=' Lost', bytes=[32, 76, 111, 115, 116], logprob=-18.0)]),
#   ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.1798739, top_logprobs=[TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.1798739), TopLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-1.804874), TopLogprob(token=' Cause', bytes=[32, 67, 97, 117, 115, 101], logprob=-9.554873)]),
# ...
#   ChatCompletionTokenLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-5.6219335e-05, top_logprobs=[TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-5.6219335e-05), TopLogprob(token=' reduction', bytes=[32, 114, 101, 100, 117, 99, 116, 105, 111, 110], logprob=-10.750056), TopLogprob(token=' management', bytes=[32, 109, 97, 110, 97, 103, 101, 109, 101, 110, 116], logprob=-11.000056)]),
#   ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.007926238, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.007926238), TopLogprob(token='.', bytes=[46], logprob=-4.8829265), TopLogprob(token=',', bytes=[44], logprob=-9.132926)]),
#   ChatCompletionTokenLogprob(token='Given', bytes=[71, 105, 118, 101, 110], logprob=-0.53048706, top_logprobs=[TopLogprob(token='Given', bytes=[71, 105, 118, 101, 110], logprob=-0.53048706), TopLogprob(token='Based', bytes=[66, 97, 115, 101, 100], logprob=-1.1554871), TopLogprob(token='Considering', bytes=[67, 111, 110, 115, 105, 100, 101, 114, 105, 110, 103], logprob=-2.530487)]),
#   ChatCompletionTokenLogprob(token=' this', bytes=[32, 116, 104, 105, 115], logprob=-0.5064295, top_logprobs=[TopLogprob(token=' this', bytes=[32, 116, 104, 105, 115], logprob=-0.5064295), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-1.2564294), TopLogprob(token=' these', bytes=[32, 116, 104, 101, 115, 101], logprob=-2.2564294)]),
#   ChatCompletionTokenLogprob(token=' analysis', bytes=[32, 97, 110, 97, 108, 121, 115, 105, 115], logprob=-0.28375793, top_logprobs=[TopLogprob(token=' analysis', bytes=[32, 97, 110, 97, 108, 121, 115, 105, 115], logprob=-0.28375793), TopLogprob(token=' reasoning', bytes=[32, 114, 101, 97, 115, 111, 110, 105, 110, 103], logprob=-1.4087579), TopLogprob(token=' evaluation', bytes=[32, 101, 118, 97, 108, 117, 97, 116, 105, 111, 110], logprob=-7.158758)]),
#   ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.0017897786, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.0017897786), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-6.5017896), TopLogprob(token=':\n', bytes=[58, 10], logprob=-8.25179)]),
#   ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.3676619, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.3676619), TopLogprob(token=' option', bytes=[32, 111, 112, 116, 105, 111, 110], logprob=-1.367662), TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-3.742662)]),
#   ChatCompletionTokenLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-0.084998146, top_logprobs=[TopLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-0.084998146), TopLogprob(token=' strongest', bytes=[32, 115, 116, 114, 111, 110, 103, 101, 115, 116], logprob=-3.4599981), TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-3.8349981)]),
#   ChatCompletionTokenLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.30525625, top_logprobs=[TopLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.30525625), TopLogprob(token=' supported', bytes=[32, 115, 117, 112, 112, 111, 114, 116, 101, 100], logprob=-2.4302564), TopLogprob(token=' plausible', bytes=[32, 112, 108, 97, 117, 115, 105, 98, 108, 101], logprob=-2.6802564)]),
#   ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.14971933, top_logprobs=[TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.14971933), TopLogprob(token=' causal', bytes=[32, 99, 97, 117, 115, 97, 108], logprob=-2.5247192), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-3.1497192)]),
#   ChatCompletionTokenLogprob(token='-and', bytes=[45, 97, 110, 100], logprob=-0.0006152204, top_logprobs=[TopLogprob(token='-and', bytes=[45, 97, 110, 100], logprob=-0.0006152204), TopLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-7.625615), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-9.000615)]),
#   ChatCompletionTokenLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-1.0280384e-06, top_logprobs=[TopLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-1.0280384e-06), TopLogprob(token='-effects', bytes=[45, 101, 102, 102, 101, 99, 116, 115], logprob=-14.375001), TopLogprob(token=' effect', bytes=[32, 101, 102, 102, 101, 99, 116], logprob=-15.625001)]),
#   ChatCompletionTokenLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.00032950565, top_logprobs=[TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.00032950565), TopLogprob(token='-', bytes=[45], logprob=-8.25033), TopLogprob(token=' relation', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110], logprob=-10.75033)]),
#   ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.002140982, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.002140982), TopLogprob(token=' here', bytes=[32, 104, 101, 114, 101], logprob=-6.877141), TopLogprob(token=' based', bytes=[32, 98, 97, 115, 101, 100], logprob=-7.877141)]),
#   ChatCompletionTokenLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-0.24231018, top_logprobs=[TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-0.24231018), TopLogprob(token=' A', bytes=[32, 65], logprob=-2.1173103), TopLogprob(token=' option', bytes=[32, 111, 112, 116, 105, 111, 110], logprob=-3.1173103)]),
#   ChatCompletionTokenLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-0.02412271, top_logprobs=[TopLogprob(token=' exercise', bytes=[32, 101, 120, 101, 114, 99, 105, 115, 101], logprob=-0.02412271), TopLogprob(token=' Exercise', bytes=[32, 69, 120, 101, 114, 99, 105, 115, 101], logprob=-4.0241227), TopLogprob(token=' "', bytes=[32, 34], logprob=-5.5241227)]),
#   ChatCompletionTokenLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-0.24621044, top_logprobs=[TopLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-0.24621044), TopLogprob(token=' leads', bytes=[32, 108, 101, 97, 100, 115], logprob=-1.6212105), TopLogprob(token=' directly', bytes=[32, 100, 105, 114, 101, 99, 116, 108, 121], logprob=-4.8712106)]),
#   ChatCompletionTokenLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-5.5122365e-07, top_logprobs=[TopLogprob(token=' weight', bytes=[32, 119, 101, 105, 103, 104, 116], logprob=-5.5122365e-07), TopLogprob(token=' Weight', bytes=[32, 87, 101, 105, 103, 104, 116], logprob=-15.875001), TopLogprob(token=' weigh', bytes=[32, 119, 101, 105, 103, 104], logprob=-16.5)]),
#   ChatCompletionTokenLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-1.9361265e-07, top_logprobs=[TopLogprob(token=' loss', bytes=[32, 108, 111, 115, 115], logprob=-1.9361265e-07), TopLogprob(token='-loss', bytes=[45, 108, 111, 115, 115], logprob=-17.375), TopLogprob(token=' reduction', bytes=[32, 114, 101, 100, 117, 99, 116, 105, 111, 110], logprob=-17.875)]),
#   ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.20593001, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.20593001), TopLogprob(token=' (', bytes=[32, 40], logprob=-2.33093), TopLogprob(token='.', bytes=[46], logprob=-2.83093)]),
#   ChatCompletionTokenLogprob(token='Therefore', bytes=[84, 104, 101, 114, 101, 102, 111, 114, 101], logprob=-1.2290561, top_logprobs=[TopLogprob(token='Therefore', bytes=[84, 104, 101, 114, 101, 102, 111, 114, 101], logprob=-1.2290561), TopLogprob(token='Thus', bytes=[84, 104, 117, 115], logprob=-1.3540561), TopLogprob(token='Final', bytes=[70, 105, 110, 97, 108], logprob=-1.3540561)]),
#   ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-4.406056e-05, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-4.406056e-05), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-10.375044), TopLogprob(token=' my', bytes=[32, 109, 121], logprob=-11.625044)]),
#   ChatCompletionTokenLogprob(token=' my', bytes=[32, 109, 121], logprob=-0.29506132, top_logprobs=[TopLogprob(token=' my', bytes=[32, 109, 121], logprob=-0.29506132), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-1.4200613), TopLogprob(token=' I', bytes=[32, 73], logprob=-4.295061)]),
#   ChatCompletionTokenLogprob(token=' final', bytes=[32, 102, 105, 110, 97, 108], logprob=-0.02914455, top_logprobs=[TopLogprob(token=' final', bytes=[32, 102, 105, 110, 97, 108], logprob=-0.02914455), TopLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-3.6541445), TopLogprob(token=' conclusion', bytes=[32, 99, 111, 110, 99, 108, 117, 115, 105, 111, 110], logprob=-6.029145)]),
#   ChatCompletionTokenLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-0.00025049195, top_logprobs=[TopLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-0.00025049195), TopLogprob(token=' decision', bytes=[32, 100, 101, 99, 105, 115, 105, 111, 110], logprob=-8.375251), TopLogprob(token=' response', bytes=[32, 114, 101, 115, 112, 111, 110, 115, 101], logprob=-12.125251)]),
#   ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.00029506313, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.00029506313), TopLogprob(token=' will', bytes=[32, 119, 105, 108, 108], logprob=-8.750295), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-10.125295)]),
#   ChatCompletionTokenLogprob(token=' <', bytes=[32, 60], logprob=-0.008094288, top_logprobs=[TopLogprob(token=' <', bytes=[32, 60], logprob=-0.008094288), TopLogprob(token=':', bytes=[58], logprob=-5.0080943), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-7.1330943)]),
#   ChatCompletionTokenLogprob(token='answer', bytes=[97, 110, 115, 119, 101, 114], logprob=-1.2664457e-06, top_logprobs=[TopLogprob(token='answer', bytes=[97, 110, 115, 119, 101, 114], logprob=-1.2664457e-06), TopLogprob(token='A', bytes=[65], logprob=-13.750001), TopLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-16.250002)]),
#   ChatCompletionTokenLogprob(token='>A', bytes=[62, 65], logprob=-2.1650272e-05, top_logprobs=[TopLogprob(token='>A', bytes=[62, 65], logprob=-2.1650272e-05), TopLogprob(token='>', bytes=[62], logprob=-10.750022), TopLogprob(token='>B', bytes=[62, 66], logprob=-16.625021)]),
#   ChatCompletionTokenLogprob(token='</', bytes=[60, 47], logprob=0.0, top_logprobs=[TopLogprob(token='</', bytes=[60, 47], logprob=0.0), TopLogprob(token=' </', bytes=[32, 60, 47], logprob=-18.25), TopLogprob(token='<', bytes=[60], logprob=-19.0)]),
#   ChatCompletionTokenLogprob(token='answer', bytes=[97, 110, 115, 119, 101, 114], logprob=0.0, top_logprobs=[TopLogprob(token='answer', bytes=[97, 110, 115, 119, 101, 114], logprob=0.0), TopLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-17.125), TopLogprob(token='answers', bytes=[97, 110, 115, 119, 101, 114, 115], logprob=-20.75)]),
#   ChatCompletionTokenLogprob(token='>', bytes=[62], logprob=-0.20578524, top_logprobs=[TopLogprob(token='>', bytes=[62], logprob=-0.20578524), TopLogprob(token='>,', bytes=[62, 44], logprob=-1.8307853), TopLogprob(token='>.', bytes=[62, 46], logprob=-3.7057853)]),
#   ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.11326159, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.11326159), TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-2.3632617), TopLogprob(token=' with', bytes=[32, 119, 105, 116, 104], logprob=-4.3632617)]),
#   ChatCompletionTokenLogprob(token=' my', bytes=[32, 109, 121], logprob=-0.027081104, top_logprobs=[TopLogprob(token=' my', bytes=[32, 109, 121], logprob=-0.027081104), TopLogprob(token=' I', bytes=[32, 73], logprob=-3.652081), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-7.277081)]),
#   ChatCompletionTokenLogprob(token=' confidence', bytes=[32, 99, 111, 110, 102, 105, 100, 101, 110, 99, 101], logprob=-5.6769813e-06, top_logprobs=[TopLogprob(token=' confidence', bytes=[32, 99, 111, 110, 102, 105, 100, 101, 110, 99, 101], logprob=-5.6769813e-06), TopLogprob(token=' level', bytes=[32, 108, 101, 118, 101, 108], logprob=-12.125006), TopLogprob(token='confidence', bytes=[99, 111, 110, 102, 105, 100, 101, 110, 99, 101], logprob=-16.625006)]),
#   ChatCompletionTokenLogprob(token=' level', bytes=[32, 108, 101, 118, 101, 108], logprob=-0.10310207, top_logprobs=[TopLogprob(token=' level', bytes=[32, 108, 101, 118, 101, 108], logprob=-0.10310207), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-2.353102), TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-5.853102)]),
#   ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.50894326, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.50894326), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-1.0089433), TopLogprob(token=' for', bytes=[32, 102, 111, 114], logprob=-3.3839433)]),
#   ChatCompletionTokenLogprob(token=' <', bytes=[32, 60], logprob=-0.0007278019, top_logprobs=[TopLogprob(token=' <', bytes=[32, 60], logprob=-0.0007278019), TopLogprob(token=' high', bytes=[32, 104, 105, 103, 104], logprob=-8.375728), TopLogprob(token=' quite', bytes=[32, 113, 117, 105, 116, 101], logprob=-8.375728)]),
#   ChatCompletionTokenLogprob(token='confidence', bytes=[99, 111, 110, 102, 105, 100, 101, 110, 99, 101], logprob=-1.9361265e-07, top_logprobs=[TopLogprob(token='confidence', bytes=[99, 111, 110, 102, 105, 100, 101, 110, 99, 101], logprob=-1.9361265e-07), TopLogprob(token='conf', bytes=[99, 111, 110, 102], logprob=-16.625), TopLogprob(token='conference', bytes=[99, 111, 110, 102, 101, 114, 101, 110, 99, 101], logprob=-18.75)]),
#   ChatCompletionTokenLogprob(token='>', bytes=[62], logprob=-6.704273e-07, top_logprobs=[TopLogprob(token='>', bytes=[62], logprob=-6.704273e-07), TopLogprob(token='>.', bytes=[62, 46], logprob=-14.250001), TopLogprob(token=' >', bytes=[32, 62], logprob=-18.75)]),
#   ChatCompletionTokenLogprob(token='0', bytes=[48], logprob=-0.00015848507, top_logprobs=[TopLogprob(token='0', bytes=[48], logprob=-0.00015848507), TopLogprob(token='1', bytes=[49], logprob=-8.750158), TopLogprob(token=' ', bytes=[32], logprob=-17.250158)]),
#   ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=0.0, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=0.0), TopLogprob(token='.</', bytes=[46, 60, 47], logprob=-23.25), TopLogprob(token='.<', bytes=[46, 60], logprob=-23.75)]),
#   ChatCompletionTokenLogprob(token='9', bytes=[57], logprob=-0.3877141, top_logprobs=[TopLogprob(token='9', bytes=[57], logprob=-0.3877141), TopLogprob(token='95', bytes=[57, 53], logprob=-1.1377141), TopLogprob(token='85', bytes=[56, 53], logprob=-7.262714)]),
#   ChatCompletionTokenLogprob(token='</', bytes=[60, 47], logprob=0.0, top_logprobs=[TopLogprob(token='</', bytes=[60, 47], logprob=0.0), TopLogprob(token=' </', bytes=[32, 60, 47], logprob=-19.5), TopLogprob(token='}</', bytes=[125, 60, 47], logprob=-21.625)]),
#   ChatCompletionTokenLogprob(token='confidence', bytes=[99, 111, 110, 102, 105, 100, 101, 110, 99, 101], logprob=-1.9361265e-07, top_logprobs=[TopLogprob(token='confidence', bytes=[99, 111, 110, 102, 105, 100, 101, 110, 99, 101], logprob=-1.9361265e-07), TopLogprob(token='conference', bytes=[99, 111, 110, 102, 101, 114, 101, 110, 99, 101], logprob=-15.75), TopLogprob(token='conf', bytes=[99, 111, 110, 102], logprob=-18.375)]),
#   ChatCompletionTokenLogprob(token='>.', bytes=[62, 46], logprob=-0.4508996, top_logprobs=[TopLogprob(token='>.', bytes=[62, 46], logprob=-0.4508996), TopLogprob(token='>', bytes=[62], logprob=-1.0758996), TopLogprob(token='>,', bytes=[62, 44], logprob=-3.8258996)])],
#  'answer_token_logprob': -2.1650272e-05,
#  'answer_choice_logprobs': {},
#  'answer_tokens_logprobs': [{'token': '>A', 'logprob': -2.1650272e-05}]}

# %%
import pandas as pd

# %%
#df = pd.read_csv('/content/drive/MyDrive/pywhy-llm/pywhyllm/tuebingen_pairs.csv')
df = pd.read_csv('/home/moleropa/repositories/master/TFM/pywhyllm/docs/notebooks/tuebingen_causality_pairs/tuebingen_pairs.csv')

# %%
df.head()
# Out:
#   Unnamed: 0        var1             var2 ground_truth  truth_ab  truth_ba  \
# 0   pair0001    Altitude      Temperature            R         1         0
# 1   pair0002    Altitude    Precipitation            R         1         0
# 2   pair0003   Longitude      Temperature            R         1         0
# 3   pair0004    Altitude   Sunshine hours            R         1         0
# 4   pair0005         Age           Length            R         1         0
#
#                                              context  \
# 0  Information for pairs0001:\n\nDWD data (Deutsc...
# 1  Information for pairs0002:\n\nDWD data (Deutsc...
# 2  Information for pairs0003:\n\nDWD data (Deutsc...
# 3  Information for pairs0004:\n\nDWD data (Deutsc...
# 4  Information for pairs0005:\n\nhttps://archive....
#
#                                            var1_desc  \
# 0  Altitude refers to the height of an object or ...
# 1  Altitude is a geographical concept referring t...
# 2  Longitude is a geographic coordinate that spec...
# 3  Altitude is a geographical term referring to t...
# 4  In the context of the Abalone dataset, the con...
#
#                                            var2_desc
# 0  Temperature is a measure of the average kineti...
# 1  Precipitation is a meteorological phenomenon t...
# 2  Temperature is a quantitative measure of the d...
# 3  Sunshine hours refer to the total number of ho...
# 4  In the context of the Abalone dataset, 'Length...

# %% [markdown]
# # Get relationship of each variable pair

# %%
llm_output : Dict[str, dict] = {}

# %% [markdown]
# ####  Variables + Straight Strategy

# %% [markdown]
# ## ALBA TEST
# modify these variables to run tests or run everything completely

# %% [markdown]
# #TO DO: ready to run everything

# %%
# # Define parameters for the experiment
# temperature = 0.3
# num_runs = 1 # Reduced for testing

# # Create saved_pairs_info to store ground truth and variable info
# saved_pairs_info = {}

# # Process only the first 3 rows for testing
# test_df = df.head(1) #or just df all dataset
# #test_df = df #or just df all dataset

# %%
# # Iterate through each pair and run multiple times
# start = time.time()

# for pair_number, values in test_df.iterrows():
#     pair_id = f"pair{pair_number:04d}"  # Create pair ID like "pair0001", "pair0002", etc.

#     saved_pairs_info[pair_id] = {
#         "var1": values['var1'],
#         "var2": values['var2'],
#         "ground_truth": values['ground_truth'],  # columna en tu dataframe
#     }
    
#     for n in range(1, num_runs + 1):  # Run 1 to 5
#         temp_dict = {}
        
#         print(f"Processing {pair_id}, run {n}/{num_runs}")
        
#         # Test A -> B direction
#         temp_dict['llm_ab'] = modeler.suggest_pairwise_relationship_with_logprobs_only_answer(
#             variable1=values['var1'], 
#             variable2=values['var2'], 
#             openai_client=azure_openai_client,
#             model_name=azure_model,
#             confidence_level=True  # Set to True to enable confidence scoring
#         )
        
#         # Test B -> A direction  
#         temp_dict['llm_ba'] = modeler.suggest_pairwise_relationship_with_logprobs_only_answer(
#             variable1=values['var2'], 
#             variable2=values['var1'], 
#             openai_client=azure_openai_client,
#             model_name=azure_model,
#             confidence_level=True  # Set to True to enable confidence scoring
#         )
        
#         # Store results with key: (pair_id, temperature, run_number)
#         llm_output[(pair_id, temperature, n )] = temp_dict
        
#         print(f"  A->B: {temp_dict['llm_ab']}, B->A: {temp_dict['llm_ba']}")

# # Calculate latencies after all processing is complete
# total_time = time.time() - start
# print(f"\nCompleted processing {len(test_df)} pairs with {num_runs} runs each")
# print(f"Total execution time: {total_time:.2f}s")

# # Calculate latencies
# avg_latency_per_pair = total_time / (len(test_df) * num_runs)  # Time per pair (both A->B and B->A) per run
# avg_latency_per_run = total_time / (len(test_df) * num_runs * 2)  # Time per individual query (A->B or B->A)

# print(f"Average time per pair (A->B + B->A): {avg_latency_per_pair:.2f}s")
# print(f"Average time per individual query: {avg_latency_per_run:.2f}s")
# Out:
# Processing pair0000, run 1/1
#   A->B: {'result': [' Altitude', ' Temperature', 'To determine the more likely cause-and-effect relationship between altitude and temperature, we need to consider the scientific principles involved.\n\n1. **Altitude and Temperature Relationship**: Generally, as altitude increases, temperature tends to decrease. This is due to the fact that the atmosphere becomes thinner at higher altitudes, leading to lower air pressure and temperature. This relationship is well-documented in meteorology.\n\n2. **Temperature and Altitude**: While temperature can influence weather patterns and atmospheric conditions, it does not directly cause changes in altitude. Altitude is a physical measurement of height above sea level, and it does not change based on temperature.\n\nGiven this reasoning, the most accurate statement is that altitude causes temperature to change, rather than the other way around.\n\nTherefore, the most likely cause-and-effect relationship is:\n\n<answer>A</answer>\n<confidence>0.95</confidence>'], 'description': 'To determine the more likely cause-and-effect relationship between altitude and temperature, we need to consider the scientific principles involved.\n\n1. **Altitude and Temperature Relationship**: Generally, as altitude increases, temperature tends to decrease. This is due to the fact that the atmosphere becomes thinner at higher altitudes, leading to lower air pressure and temperature. This relationship is well-documented in meteorology.\n\n2. **Temperature and Altitude**: While temperature can influence weather patterns and atmospheric conditions, it does not directly cause changes in altitude. Altitude is a physical measurement of height above sea level, and it does not change based on temperature.\n\nGiven this reasoning, the most accurate statement is that altitude causes temperature to change, rather than the other way around.\n\nTherefore, the most likely cause-and-effect relationship is:\n\n<answer>A</answer>\n<confidence>0.95</confidence>', 'answer': 'A', 'confidence_score': 0.95, 'logprobs': [ChatCompletionTokenLogprob(token='To', bytes=[84, 111], logprob=-0.033306416, top_logprobs=[TopLogprob(token='To', bytes=[84, 111], logprob=-0.033306416), TopLogprob(token='In', bytes=[73, 110], logprob=-4.2833066), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-4.6583066)]), ChatCompletionTokenLogprob(token=' determine', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101], logprob=-0.8183077, top_logprobs=[TopLogprob(token=' determine', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101], logprob=-0.8183077), TopLogprob(token=' evaluate', bytes=[32, 101, 118, 97, 108, 117, 97, 116, 101], logprob=-1.0683076), TopLogprob(token=' analyze', bytes=[32, 97, 110, 97, 108, 121, 122, 101], logprob=-2.0683076)]), ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.4741702, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.4741702), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.9741702), TopLogprob(token=' whether', bytes=[32, 119, 104, 101, 116, 104, 101, 114], logprob=-9.724171)]), ChatCompletionTokenLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.1997782, top_logprobs=[TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.1997782), TopLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-1.1997782), TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-1.1997782)]), ChatCompletionTokenLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.0011817772, top_logprobs=[TopLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.0011817772), TopLogprob(token=' plausible', bytes=[32, 112, 108, 97, 117, 115, 105, 98, 108, 101], logprob=-6.8761816), TopLogprob(token=' probable', bytes=[32, 112, 114, 111, 98, 97, 98, 108, 101], logprob=-8.876182)]), ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob= ...
#
# Completed processing 1 pairs with 1 runs each
# Total execution time: 16.78s
# Average time per pair (A->B + B->A): 16.78s
# Average time per individual query: 8.39s
#   A->B: {'result': [' Altitude', ' Temperature', 'To determine the more likely cause-and-effect relationship between altitude and temperature, we need to consider the scientific principles involved.\n\n1. **Altitude and Temperature Relationship**: Generally, as altitude increases, temperature tends to decrease. This is due to the fact that the atmosphere becomes thinner at higher altitudes, leading to lower air pressure and temperature. This relationship is well-documented in meteorology.\n\n2. **Temperature and Altitude**: While temperature can influence weather patterns and atmospheric conditions, it does not directly cause changes in altitude. Altitude is a physical measurement of height above sea level, and it does not change based on temperature.\n\nGiven this reasoning, the most accurate statement is that altitude causes temperature to change, rather than the other way around.\n\nTherefore, the most likely cause-and-effect relationship is:\n\n<answer>A</answer>\n<confidence>0.95</confidence>'], 'description': 'To determine the more likely cause-and-effect relationship between altitude and temperature, we need to consider the scientific principles involved.\n\n1. **Altitude and Temperature Relationship**: Generally, as altitude increases, temperature tends to decrease. This is due to the fact that the atmosphere becomes thinner at higher altitudes, leading to lower air pressure and temperature. This relationship is well-documented in meteorology.\n\n2. **Temperature and Altitude**: While temperature can influence weather patterns and atmospheric conditions, it does not directly cause changes in altitude. Altitude is a physical measurement of height above sea level, and it does not change based on temperature.\n\nGiven this reasoning, the most accurate statement is that altitude causes temperature to change, rather than the other way around.\n\nTherefore, the most likely cause-and-effect relationship is:\n\n<answer>A</answer>\n<confidence>0.95</confidence>', 'answer': 'A', 'confidence_score': 0.95, 'logprobs': [ChatCompletionTokenLogprob(token='To', bytes=[84, 111], logprob=-0.033306416, top_logprobs=[TopLogprob(token='To', bytes=[84, 111], logprob=-0.033306416), TopLogprob(token='In', bytes=[73, 110], logprob=-4.2833066), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-4.6583066)]), ChatCompletionTokenLogprob(token=' determine', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101], logprob=-0.8183077, top_logprobs=[TopLogprob(token=' determine', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101], logprob=-0.8183077), TopLogprob(token=' evaluate', bytes=[32, 101, 118, 97, 108, 117, 97, 116, 101], logprob=-1.0683076), TopLogprob(token=' analyze', bytes=[32, 97, 110, 97, 108, 121, 122, 101], logprob=-2.0683076)]), ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.4741702, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.4741702), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.9741702), TopLogprob(token=' whether', bytes=[32, 119, 104, 101, 116, 104, 101, 114], logprob=-9.724171)]), ChatCompletionTokenLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.1997782, top_logprobs=[TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.1997782), TopLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-1.1997782), TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-1.1997782)]), ChatCompletionTokenLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.0011817772, top_logprobs=[TopLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.0011817772), TopLogprob(token=' plausible', bytes=[32, 112, 108, 97, 117, 115, 105, 98, 108, 101], logprob=-6.8761816), TopLogprob(token=' probable', bytes=[32, 112, 114, 111, 98, 97, 98, 108, 101], logprob=-8.876182)]), ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob= ...
#
# Completed processing 1 pairs with 1 runs each
# Total execution time: 16.78s
# Average time per pair (A->B + B->A): 16.78s
# Average time per individual query: 8.39s

# %%
temp_dict
# Out:
# {'llm_ab': {'result': [' Altitude',
#    ' Temperature',
#    'To determine the more likely cause-and-effect relationship between altitude and temperature, we need to consider the scientific principles involved.\n\n1. **Altitude and Temperature Relationship**: Generally, as altitude increases, temperature tends to decrease. This is due to the fact that the atmosphere becomes thinner at higher altitudes, leading to lower air pressure and temperature. This relationship is well-documented in meteorology.\n\n2. **Temperature and Altitude**: While temperature can influence weather patterns and atmospheric conditions, it does not directly cause changes in altitude. Altitude is a physical measurement of height above sea level, and it does not change based on temperature.\n\nGiven this reasoning, the most accurate statement is that altitude causes temperature to change, rather than the other way around.\n\nTherefore, the most likely cause-and-effect relationship is:\n\n<answer>A</answer>\n<confidence>0.95</confidence>'],
#   'description': 'To determine the more likely cause-and-effect relationship between altitude and temperature, we need to consider the scientific principles involved.\n\n1. **Altitude and Temperature Relationship**: Generally, as altitude increases, temperature tends to decrease. This is due to the fact that the atmosphere becomes thinner at higher altitudes, leading to lower air pressure and temperature. This relationship is well-documented in meteorology.\n\n2. **Temperature and Altitude**: While temperature can influence weather patterns and atmospheric conditions, it does not directly cause changes in altitude. Altitude is a physical measurement of height above sea level, and it does not change based on temperature.\n\nGiven this reasoning, the most accurate statement is that altitude causes temperature to change, rather than the other way around.\n\nTherefore, the most likely cause-and-effect relationship is:\n\n<answer>A</answer>\n<confidence>0.95</confidence>',
#   'answer': 'A',
#   'confidence_score': 0.95,
#   'logprobs': [ChatCompletionTokenLogprob(token='To', bytes=[84, 111], logprob=-0.033306416, top_logprobs=[TopLogprob(token='To', bytes=[84, 111], logprob=-0.033306416), TopLogprob(token='In', bytes=[73, 110], logprob=-4.2833066), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-4.6583066)]),
#    ChatCompletionTokenLogprob(token=' determine', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101], logprob=-0.8183077, top_logprobs=[TopLogprob(token=' determine', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101], logprob=-0.8183077), TopLogprob(token=' evaluate', bytes=[32, 101, 118, 97, 108, 117, 97, 116, 101], logprob=-1.0683076), TopLogprob(token=' analyze', bytes=[32, 97, 110, 97, 108, 121, 122, 101], logprob=-2.0683076)]),
#    ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.4741702, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.4741702), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.9741702), TopLogprob(token=' whether', bytes=[32, 119, 104, 101, 116, 104, 101, 114], logprob=-9.724171)]),
#    ChatCompletionTokenLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.1997782, top_logprobs=[TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.1997782), TopLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-1.1997782), TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-1.1997782)]),
#    ChatCompletionTokenLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.0011817772, top_logprobs=[TopLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-0.0011817772), TopLogprob(token=' plausible', bytes=[32, 112, 108, 97, 117, 115, 105, 98, 108, 101], logprob=-6.8761816), TopLogprob(token=' probable', bytes=[32, 112, 114, 111, 98, 97, 98, 108, 101], logprob=-8.876182)]),
#    ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.0028404184, top_logprobs=[TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.0028404184), TopLogprob(token=' causal', bytes=[32, 99, 97, 117, 115, 97, 108], logprob=-5.8778405), TopLogprob(token=' caus', bytes=[32, 99, 97, 117, 115], logprob=-10.62784)]),
#    ChatCompletionTokenLogprob(token='-and', bytes=[45, 97, 110, 100], logprob=-1.7239736e-05, top_logprobs=[TopLogprob(token='-and', bytes=[45, 97, 110, 100], logprob=-1.7239736e-05), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-11.500017), TopLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-11.875017)]),
#    ChatCompletionTokenLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-7.89631e-07, top_logprobs=[TopLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-7.89631e-07), TopLogprob(token='-effects', bytes=[45, 101, 102, 102, 101, 99, 116, 115], logprob=-14.375001), TopLogprob(token=' effect', bytes=[32, 101, 102, 102, 101, 99, 116], logprob=-16.0)]),
#    ChatCompletionTokenLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.0005151443, top_logprobs=[TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.0005151443), TopLogprob(token='-', bytes=[45], logprob=-7.875515), TopLogprob(token=' relationships', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112, 115], logprob=-9.125515)]),
#    ChatCompletionTokenLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-0.095002435, top_logprobs=[TopLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-0.095002435), TopLogprob(token=',', bytes=[44], logprob=-2.4700024), TopLogprob(token=' among', bytes=[32, 97, 109, 111, 110, 103], logprob=-5.2200027)]),
#    ChatCompletionTokenLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-0.0036490108, top_logprobs=[TopLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-0.0036490108), TopLogprob(token=' Alt', bytes=[32, 65, 108, 116], logprob=-5.753649), TopLogprob(token=' "', bytes=[32, 34], logprob=-7.753649)]),
#    ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-6.704273e-07, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-6.704273e-07), TopLogprob(token=' (', bytes=[32, 40], logprob=-14.250001), TopLogprob(token=',', bytes=[44], logprob=-17.75)]),
#    ChatCompletionTokenLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=0.0, top_logprobs=[TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=0.0), TopLogprob(token=' temperatures', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101, 115], logprob=-19.625), TopLogprob(token='temperature', bytes=[116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-20.125)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.00043293412, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.00043293412), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-7.750433), TopLogprob(token=' we', bytes=[32, 119, 101], logprob=-14.125433)]),
#    ChatCompletionTokenLogprob(token=' we', bytes=[32, 119, 101], logprob=-0.03881731, top_logprobs=[TopLogprob(token=' we', bytes=[32, 119, 101], logprob=-0.03881731), TopLogprob(token=" let's", bytes=[32, 108, 101, 116, 39, 115], logprob=-3.7888174), TopLogprob(token=" it's", bytes=[32, 105, 116, 39, 115], logprob=-4.7888174)]),
#    ChatCompletionTokenLogprob(token=' need', bytes=[32, 110, 101, 101, 100], logprob=-0.76960874, top_logprobs=[TopLogprob(token=' need', bytes=[32, 110, 101, 101, 100], logprob=-0.76960874), TopLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-1.2696087), TopLogprob(token=' should', bytes=[32, 115, 104, 111, 117, 108, 100], logprob=-2.0196087)]),
#    ChatCompletionTokenLogprob(token=' to', bytes=[32, 116, 111], logprob=-1.8624639e-06, top_logprobs=[TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-1.8624639e-06), TopLogprob(token=' a', bytes=[32, 97], logprob=-14.125002), TopLogprob(token=' some', bytes=[32, 115, 111, 109, 101], logprob=-14.375002)]),
#    ChatCompletionTokenLogprob(token=' consider', bytes=[32, 99, 111, 110, 115, 105, 100, 101, 114], logprob=-0.14016646, top_logprobs=[TopLogprob(token=' consider', bytes=[32, 99, 111, 110, 115, 105, 100, 101, 114], logprob=-0.14016646), TopLogprob(token=' analyze', bytes=[32, 97, 110, 97, 108, 121, 122, 101], logprob=-2.7651665), TopLogprob(token=' understand', bytes=[32, 117, 110, 100, 101, 114, 115, 116, 97, 110, 100], logprob=-3.5151665)]),
#    ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.47643262, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.47643262), TopLogprob(token=' how', bytes=[32, 104, 111, 119], logprob=-1.1014326), TopLogprob(token=' what', bytes=[32, 119, 104, 97, 116], logprob=-3.9764326)]),
#    ChatCompletionTokenLogprob(token=' scientific', bytes=[32, 115, 99, 105, 101, 110, 116, 105, 102, 105, 99], logprob=-0.7370364, top_logprobs=[TopLogprob(token=' scientific', bytes=[32, 115, 99, 105, 101, 110, 116, 105, 102, 105, 99], logprob=-0.7370364), TopLogprob(token=' established', bytes=[32, 101, 115, 116, 97, 98, 108, 105, 115, 104, 101, 100], logprob=-1.6120365), TopLogprob(token=' general', bytes=[32, 103, 101, 110, 101, 114, 97, 108], logprob=-2.7370365)]),
#    ChatCompletionTokenLogprob(token=' principles', bytes=[32, 112, 114, 105, 110, 99, 105, 112, 108, 101, 115], logprob=-0.40149394, top_logprobs=[TopLogprob(token=' principles', bytes=[32, 112, 114, 105, 110, 99, 105, 112, 108, 101, 115], logprob=-0.40149394), TopLogprob(token=' understanding', bytes=[32, 117, 110, 100, 101, 114, 115, 116, 97, 110, 100, 105, 110, 103], logprob=-1.1514939), TopLogprob(token=' context', bytes=[32, 99, 111, 110, 116, 101, 120, 116], logprob=-4.901494)]),
#    ChatCompletionTokenLogprob(token=' involved', bytes=[32, 105, 110, 118, 111, 108, 118, 101, 100], logprob=-1.0393925, top_logprobs=[TopLogprob(token=' involved', bytes=[32, 105, 110, 118, 111, 108, 118, 101, 100], logprob=-1.0393925), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-1.4143925), TopLogprob(token=' governing', bytes=[32, 103, 111, 118, 101, 114, 110, 105, 110, 103], logprob=-1.6643925)]),
#    ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.4924505, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.4924505), TopLogprob(token='.', bytes=[46], logprob=-1.1174505), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-2.8674505)]),
#    ChatCompletionTokenLogprob(token='1', bytes=[49], logprob=-0.9290986, top_logprobs=[TopLogprob(token='1', bytes=[49], logprob=-0.9290986), TopLogprob(token='A', bytes=[65], logprob=-1.0540986), TopLogprob(token='Altitude', bytes=[65, 108, 116, 105, 116, 117, 100, 101], logprob=-2.4290986)]),
#    ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-7.89631e-07, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-7.89631e-07), TopLogprob(token=')', bytes=[41], logprob=-14.375001), TopLogprob(token='.A', bytes=[46, 65], logprob=-17.0)]),
#    ChatCompletionTokenLogprob(token=' **', bytes=[32, 42, 42], logprob=-0.031041974, top_logprobs=[TopLogprob(token=' **', bytes=[32, 42, 42], logprob=-0.031041974), TopLogprob(token=' Alt', bytes=[32, 65, 108, 116], logprob=-4.281042), TopLogprob(token=' Generally', bytes=[32, 71, 101, 110, 101, 114, 97, 108, 108, 121], logprob=-4.906042)]),
#    ChatCompletionTokenLogprob(token='Altitude', bytes=[65, 108, 116, 105, 116, 117, 100, 101], logprob=-0.039544865, top_logprobs=[TopLogprob(token='Altitude', bytes=[65, 108, 116, 105, 116, 117, 100, 101], logprob=-0.039544865), TopLogprob(token='Understanding', bytes=[85, 110, 100, 101, 114, 115, 116, 97, 110, 100, 105, 110, 103], logprob=-3.4145448), TopLogprob(token='Effect', bytes=[69, 102, 102, 101, 99, 116], logprob=-6.539545)]),
#    ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.17537507, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.17537507), TopLogprob(token=' affects', bytes=[32, 97, 102, 102, 101, 99, 116, 115], logprob=-2.800375), TopLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-3.550375)]),
#    ChatCompletionTokenLogprob(token=' Temperature', bytes=[32, 84, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.0111366045, top_logprobs=[TopLogprob(token=' Temperature', bytes=[32, 84, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.0111366045), TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-5.0111365), TopLogprob(token=' its', bytes=[32, 105, 116, 115], logprob=-5.8861365)]),
#    ChatCompletionTokenLogprob(token=' Relationship', bytes=[32, 82, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.38940984, top_logprobs=[TopLogprob(token=' Relationship', bytes=[32, 82, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.38940984), TopLogprob(token='**', bytes=[42, 42], logprob=-1.2644098), TopLogprob(token=':**', bytes=[58, 42, 42], logprob=-3.6394098)]),
#    ChatCompletionTokenLogprob(token='**', bytes=[42, 42], logprob=-0.020910168, top_logprobs=[TopLogprob(token='**', bytes=[42, 42], logprob=-0.020910168), TopLogprob(token=':**', bytes=[58, 42, 42], logprob=-4.2709103), TopLogprob(token=':', bytes=[58], logprob=-5.0209103)]),
#    ChatCompletionTokenLogprob(token=':', bytes=[58], logprob=-0.038078442, top_logprobs=[TopLogprob(token=':', bytes=[58], logprob=-0.038078442), TopLogprob(token=':\n', bytes=[58, 10], logprob=-3.2880785), TopLogprob(token=' -', bytes=[32, 45], logprob=-10.288078)]),
#    ChatCompletionTokenLogprob(token=' Generally', bytes=[32, 71, 101, 110, 101, 114, 97, 108, 108, 121], logprob=-0.61006624, top_logprobs=[TopLogprob(token=' Generally', bytes=[32, 71, 101, 110, 101, 114, 97, 108, 108, 121], logprob=-0.61006624), TopLogprob(token=' It', bytes=[32, 73, 116], logprob=-1.6100662), TopLogprob(token=' In', bytes=[32, 73, 110], logprob=-2.2350662)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.0024152535, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.0024152535), TopLogprob(token=' speaking', bytes=[32, 115, 112, 101, 97, 107, 105, 110, 103], logprob=-6.502415), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-7.252415)]),
#    ChatCompletionTokenLogprob(token=' as', bytes=[32, 97, 115], logprob=-0.10196002, top_logprobs=[TopLogprob(token=' as', bytes=[32, 97, 115], logprob=-0.10196002), TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-3.22696), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-3.72696)]),
#    ChatCompletionTokenLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-0.003476055, top_logprobs=[TopLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-0.003476055), TopLogprob(token=' one', bytes=[32, 111, 110, 101], logprob=-6.378476), TopLogprob(token=' you', bytes=[32, 121, 111, 117], logprob=-6.503476)]),
#    ChatCompletionTokenLogprob(token=' increases', bytes=[32, 105, 110, 99, 114, 101, 97, 115, 101, 115], logprob=-0.00013691289, top_logprobs=[TopLogprob(token=' increases', bytes=[32, 105, 110, 99, 114, 101, 97, 115, 101, 115], logprob=-0.00013691289), TopLogprob(token=' (', bytes=[32, 40], logprob=-9.000137), TopLogprob(token=' rises', bytes=[32, 114, 105, 115, 101, 115], logprob=-11.625137)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.006296699, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.006296699), TopLogprob(token=' (', bytes=[32, 40], logprob=-5.5062966), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-6.1312966)]),
#    ChatCompletionTokenLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.18628627, top_logprobs=[TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.18628627), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-1.8112862), TopLogprob(token=' air', bytes=[32, 97, 105, 114], logprob=-5.8112864)]),
#    ChatCompletionTokenLogprob(token=' tends', bytes=[32, 116, 101, 110, 100, 115], logprob=-0.48241964, top_logprobs=[TopLogprob(token=' tends', bytes=[32, 116, 101, 110, 100, 115], logprob=-0.48241964), TopLogprob(token=' decreases', bytes=[32, 100, 101, 99, 114, 101, 97, 115, 101, 115], logprob=-0.9824196), TopLogprob(token=' typically', bytes=[32, 116, 121, 112, 105, 99, 97, 108, 108, 121], logprob=-4.8574195)]),
#    ChatCompletionTokenLogprob(token=' to', bytes=[32, 116, 111], logprob=-1.9816675e-06, top_logprobs=[TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-1.9816675e-06), TopLogprob(token=' typically', bytes=[32, 116, 121, 112, 105, 99, 97, 108, 108, 121], logprob=-13.750002), TopLogprob(token=' generally', bytes=[32, 103, 101, 110, 101, 114, 97, 108, 108, 121], logprob=-15.500002)]),
#    ChatCompletionTokenLogprob(token=' decrease', bytes=[32, 100, 101, 99, 114, 101, 97, 115, 101], logprob=-3.9292416e-05, top_logprobs=[TopLogprob(token=' decrease', bytes=[32, 100, 101, 99, 114, 101, 97, 115, 101], logprob=-3.9292416e-05), TopLogprob(token=' drop', bytes=[32, 100, 114, 111, 112], logprob=-10.375039), TopLogprob(token=' decreases', bytes=[32, 100, 101, 99, 114, 101, 97, 115, 101, 115], logprob=-12.375039)]),
#    ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-0.02639656, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-0.02639656), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-4.2763968), TopLogprob(token=' due', bytes=[32, 100, 117, 101], logprob=-4.7763968)]),
#    ChatCompletionTokenLogprob(token=' This', bytes=[32, 84, 104, 105, 115], logprob=-0.0010268545, top_logprobs=[TopLogprob(token=' This', bytes=[32, 84, 104, 105, 115], logprob=-0.0010268545), TopLogprob(token=' The', bytes=[32, 84, 104, 101], logprob=-7.3760266), TopLogprob(token=' In', bytes=[32, 73, 110], logprob=-8.501027)]),
#    ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.17086071, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.17086071), TopLogprob(token=' phenomenon', bytes=[32, 112, 104, 101, 110, 111, 109, 101, 110, 111, 110], logprob=-2.0458608), TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-4.420861)]),
#    ChatCompletionTokenLogprob(token=' due', bytes=[32, 100, 117, 101], logprob=-0.7306004, top_logprobs=[TopLogprob(token=' due', bytes=[32, 100, 117, 101], logprob=-0.7306004), TopLogprob(token=' a', bytes=[32, 97], logprob=-1.3556004), TopLogprob(token=' observed', bytes=[32, 111, 98, 115, 101, 114, 118, 101, 100], logprob=-2.7306004)]),
#    ChatCompletionTokenLogprob(token=' to', bytes=[32, 116, 111], logprob=-0.000110457004, top_logprobs=[TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-0.000110457004), TopLogprob(token=' primarily', bytes=[32, 112, 114, 105, 109, 97, 114, 105, 108, 121], logprob=-10.125111), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-10.375111)]),
#    ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.022815373, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.022815373), TopLogprob(token=' several', bytes=[32, 115, 101, 118, 101, 114, 97, 108], logprob=-4.772815), TopLogprob(token=' atmospheric', bytes=[32, 97, 116, 109, 111, 115, 112, 104, 101, 114, 105, 99], logprob=-4.897815)]),
#    ChatCompletionTokenLogprob(token=' fact', bytes=[32, 102, 97, 99, 116], logprob=-0.9304888, top_logprobs=[TopLogprob(token=' fact', bytes=[32, 102, 97, 99, 116], logprob=-0.9304888), TopLogprob(token=' thinning', bytes=[32, 116, 104, 105, 110, 110, 105, 110, 103], logprob=-1.4304888), TopLogprob(token=' way', bytes=[32, 119, 97, 121], logprob=-1.9304888)]),
#    ChatCompletionTokenLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-9.0883464e-07, top_logprobs=[TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-9.0883464e-07), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-14.250001), TopLogprob(token=' as', bytes=[32, 97, 115], logprob=-17.0)]),
#    ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.10369619, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.10369619), TopLogprob(token=' higher', bytes=[32, 104, 105, 103, 104, 101, 114], logprob=-3.353696), TopLogprob(token=' air', bytes=[32, 97, 105, 114], logprob=-3.728696)]),
#    ChatCompletionTokenLogprob(token=' atmosphere', bytes=[32, 97, 116, 109, 111, 115, 112, 104, 101, 114, 101], logprob=-0.08096032, top_logprobs=[TopLogprob(token=' atmosphere', bytes=[32, 97, 116, 109, 111, 115, 112, 104, 101, 114, 101], logprob=-0.08096032), TopLogprob(token=' air', bytes=[32, 97, 105, 114], logprob=-3.2059603), TopLogprob(token=" Earth's", bytes=[32, 69, 97, 114, 116, 104, 39, 115], logprob=-3.5809603)]),
#    ChatCompletionTokenLogprob(token=' becomes', bytes=[32, 98, 101, 99, 111, 109, 101, 115], logprob=-0.75654864, top_logprobs=[TopLogprob(token=' becomes', bytes=[32, 98, 101, 99, 111, 109, 101, 115], logprob=-0.75654864), TopLogprob(token=' gets', bytes=[32, 103, 101, 116, 115], logprob=-1.2565486), TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-2.1315486)]),
#    ChatCompletionTokenLogprob(token=' thinner', bytes=[32, 116, 104, 105, 110, 110, 101, 114], logprob=-0.25208178, top_logprobs=[TopLogprob(token=' thinner', bytes=[32, 116, 104, 105, 110, 110, 101, 114], logprob=-0.25208178), TopLogprob(token=' less', bytes=[32, 108, 101, 115, 115], logprob=-1.5020818), TopLogprob(token=' cooler', bytes=[32, 99, 111, 111, 108, 101, 114], logprob=-9.127082)]),
#    ChatCompletionTokenLogprob(token=' at', bytes=[32, 97, 116], logprob=-0.15869492, top_logprobs=[TopLogprob(token=' at', bytes=[32, 97, 116], logprob=-0.15869492), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-2.533695), TopLogprob(token=' with', bytes=[32, 119, 105, 116, 104], logprob=-3.033695)]),
#    ChatCompletionTokenLogprob(token=' higher', bytes=[32, 104, 105, 103, 104, 101, 114], logprob=-0.00049131457, top_logprobs=[TopLogprob(token=' higher', bytes=[32, 104, 105, 103, 104, 101, 114], logprob=-0.00049131457), TopLogprob(token=' greater', bytes=[32, 103, 114, 101, 97, 116, 101, 114], logprob=-7.875491), TopLogprob(token=' high', bytes=[32, 104, 105, 103, 104], logprob=-9.125491)]),
#    ChatCompletionTokenLogprob(token=' alt', bytes=[32, 97, 108, 116], logprob=-0.11289215, top_logprobs=[TopLogprob(token=' alt', bytes=[32, 97, 108, 116], logprob=-0.11289215), TopLogprob(token=' elevations', bytes=[32, 101, 108, 101, 118, 97, 116, 105, 111, 110, 115], logprob=-2.2378922), TopLogprob(token=' levels', bytes=[32, 108, 101, 118, 101, 108, 115], logprob=-10.612892)]),
#    ChatCompletionTokenLogprob(token='itudes', bytes=[105, 116, 117, 100, 101, 115], logprob=-4.3202e-07, top_logprobs=[TopLogprob(token='itudes', bytes=[105, 116, 117, 100, 101, 115], logprob=-4.3202e-07), TopLogprob(token='itud', bytes=[105, 116, 117, 100], logprob=-15.0), TopLogprob(token='ities', bytes=[105, 116, 105, 101, 115], logprob=-17.75)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.02301158, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.02301158), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-3.8980117), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-6.6480117)]),
#    ChatCompletionTokenLogprob(token=' leading', bytes=[32, 108, 101, 97, 100, 105, 110, 103], logprob=-0.7402082, top_logprobs=[TopLogprob(token=' leading', bytes=[32, 108, 101, 97, 100, 105, 110, 103], logprob=-0.7402082), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-1.2402081), TopLogprob(token=' resulting', bytes=[32, 114, 101, 115, 117, 108, 116, 105, 110, 103], logprob=-1.8652081)]),
#    ChatCompletionTokenLogprob(token=' to', bytes=[32, 116, 111], logprob=-3.070975e-05, top_logprobs=[TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-3.070975e-05), TopLogprob(token=' less', bytes=[32, 108, 101, 115, 115], logprob=-10.7500305), TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-12.3750305)]),
#    ChatCompletionTokenLogprob(token=' lower', bytes=[32, 108, 111, 119, 101, 114], logprob=-0.5719692, top_logprobs=[TopLogprob(token=' lower', bytes=[32, 108, 111, 119, 101, 114], logprob=-0.5719692), TopLogprob(token=' less', bytes=[32, 108, 101, 115, 115], logprob=-1.0719693), TopLogprob(token=' a', bytes=[32, 97], logprob=-3.0719693)]),
#    ChatCompletionTokenLogprob(token=' air', bytes=[32, 97, 105, 114], logprob=-0.24867167, top_logprobs=[TopLogprob(token=' air', bytes=[32, 97, 105, 114], logprob=-0.24867167), TopLogprob(token=' pressure', bytes=[32, 112, 114, 101, 115, 115, 117, 114, 101], logprob=-2.1236718), TopLogprob(token=' temperatures', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101, 115], logprob=-2.6236718)]),
#    ChatCompletionTokenLogprob(token=' pressure', bytes=[32, 112, 114, 101, 115, 115, 117, 114, 101], logprob=-0.0102840075, top_logprobs=[TopLogprob(token=' pressure', bytes=[32, 112, 114, 101, 115, 115, 117, 114, 101], logprob=-0.0102840075), TopLogprob(token=' temperatures', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101, 115], logprob=-5.385284), TopLogprob(token=' pressures', bytes=[32, 112, 114, 101, 115, 115, 117, 114, 101, 115], logprob=-5.385284)]),
#    ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.0076809195, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.0076809195), TopLogprob(token=',', bytes=[44], logprob=-5.007681), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-7.007681)]),
#    ChatCompletionTokenLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-1.3576319, top_logprobs=[TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-1.3576319), TopLogprob(token=' lower', bytes=[32, 108, 111, 119, 101, 114], logprob=-1.9826319), TopLogprob(token=' cooler', bytes=[32, 99, 111, 111, 108, 101, 114], logprob=-1.9826319)]),
#    ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-0.589928, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-0.589928), TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.839928), TopLogprob(token='.\n', bytes=[46, 10], logprob=-4.839928)]),
#    ChatCompletionTokenLogprob(token=' This', bytes=[32, 84, 104, 105, 115], logprob=-0.84394443, top_logprobs=[TopLogprob(token=' This', bytes=[32, 84, 104, 105, 115], logprob=-0.84394443), TopLogprob(token=' \n\n', bytes=[32, 10, 10], logprob=-1.3439444), TopLogprob(token=' Therefore', bytes=[32, 84, 104, 101, 114, 101, 102, 111, 114, 101], logprob=-1.7189444)]),
#    ChatCompletionTokenLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-1.1708004, top_logprobs=[TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-1.1708004), TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-1.2958004), TopLogprob(token=' established', bytes=[32, 101, 115, 116, 97, 98, 108, 105, 115, 104, 101, 100], logprob=-2.7958004)]),
#    ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.4885701, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.4885701), TopLogprob(token=' suggests', bytes=[32, 115, 117, 103, 103, 101, 115, 116, 115], logprob=-1.7385701), TopLogprob(token=' has', bytes=[32, 104, 97, 115], logprob=-2.6135702)]),
#    ChatCompletionTokenLogprob(token=' well', bytes=[32, 119, 101, 108, 108], logprob=-0.4111318, top_logprobs=[TopLogprob(token=' well', bytes=[32, 119, 101, 108, 108], logprob=-0.4111318), TopLogprob(token=' a', bytes=[32, 97], logprob=-2.6611319), TopLogprob(token=' widely', bytes=[32, 119, 105, 100, 101, 108, 121], logprob=-2.9111319)]),
#    ChatCompletionTokenLogprob(token='-d', bytes=[45, 100], logprob=-0.69401073, top_logprobs=[TopLogprob(token='-d', bytes=[45, 100], logprob=-0.69401073), TopLogprob(token='-established', bytes=[45, 101, 115, 116, 97, 98, 108, 105, 115, 104, 101, 100], logprob=-1.3190107), TopLogprob(token=' established', bytes=[32, 101, 115, 116, 97, 98, 108, 105, 115, 104, 101, 100], logprob=-2.0690107)]),
#    ChatCompletionTokenLogprob(token='ocumented', bytes=[111, 99, 117, 109, 101, 110, 116, 101, 100], logprob=-1.147242e-06, top_logprobs=[TopLogprob(token='ocumented', bytes=[111, 99, 117, 109, 101, 110, 116, 101, 100], logprob=-1.147242e-06), TopLogprob(token=' documented', bytes=[32, 100, 111, 99, 117, 109, 101, 110, 116, 101, 100], logprob=-14.375001), TopLogprob(token='etermined', bytes=[101, 116, 101, 114, 109, 105, 110, 101, 100], logprob=-15.375001)]),
#    ChatCompletionTokenLogprob(token=' in', bytes=[32, 105, 110], logprob=-0.07713375, top_logprobs=[TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-0.07713375), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-2.7021337), TopLogprob(token=',', bytes=[44], logprob=-5.2021337)]),
#    ChatCompletionTokenLogprob(token=' meteor', bytes=[32, 109, 101, 116, 101, 111, 114], logprob=-0.4808206, top_logprobs=[TopLogprob(token=' meteor', bytes=[32, 109, 101, 116, 101, 111, 114], logprob=-0.4808206), TopLogprob(token=' atmospheric', bytes=[32, 97, 116, 109, 111, 115, 112, 104, 101, 114, 105, 99], logprob=-1.1058207), TopLogprob(token=' environmental', bytes=[32, 101, 110, 118, 105, 114, 111, 110, 109, 101, 110, 116, 97, 108], logprob=-3.7308207)]),
#    ChatCompletionTokenLogprob(token='ology', bytes=[111, 108, 111, 103, 121], logprob=-0.11282528, top_logprobs=[TopLogprob(token='ology', bytes=[111, 108, 111, 103, 121], logprob=-0.11282528), TopLogprob(token='ological', bytes=[111, 108, 111, 103, 105, 99, 97, 108], logprob=-2.2378254), TopLogprob(token='ologic', bytes=[111, 108, 111, 103, 105, 99], logprob=-13.237825)]),
#    ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.5982047, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.5982047), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.8482047), TopLogprob(token=',', bytes=[44], logprob=-4.2232046)]),
#    ChatCompletionTokenLogprob(token='2', bytes=[50], logprob=-0.005207671, top_logprobs=[TopLogprob(token='2', bytes=[50], logprob=-0.005207671), TopLogprob(token='Given', bytes=[71, 105, 118, 101, 110], logprob=-6.1302075), TopLogprob(token='-', bytes=[45], logprob=-6.7552075)]),
#    ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=0.0, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=0.0), TopLogprob(token='.A', bytes=[46, 65], logprob=-21.375), TopLogprob(token='-', bytes=[45], logprob=-22.625)]),
#    ChatCompletionTokenLogprob(token=' **', bytes=[32, 42, 42], logprob=-0.0003807449, top_logprobs=[TopLogprob(token=' **', bytes=[32, 42, 42], logprob=-0.0003807449), TopLogprob(token=' An', bytes=[32, 65, 110], logprob=-8.7503805), TopLogprob(token=' Evalu', bytes=[32, 69, 118, 97, 108, 117], logprob=-9.7503805)]),
#    ChatCompletionTokenLogprob(token='Temperature', bytes=[84, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.52409834, top_logprobs=[TopLogprob(token='Temperature', bytes=[84, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.52409834), TopLogprob(token='Reverse', bytes=[82, 101, 118, 101, 114, 115, 101], logprob=-1.8990984), TopLogprob(token='Re', bytes=[82, 101], logprob=-2.5240984)]),
#    ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.708093, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.708093), TopLogprob(token=' Affect', bytes=[32, 65, 102, 102, 101, 99, 116], logprob=-1.5830929), TopLogprob(token="'s", bytes=[39, 115], logprob=-2.333093)]),
#    ChatCompletionTokenLogprob(token=' Alt', bytes=[32, 65, 108, 116], logprob=-0.0003857478, top_logprobs=[TopLogprob(token=' Alt', bytes=[32, 65, 108, 116], logprob=-0.0003857478), TopLogprob(token=' Its', bytes=[32, 73, 116, 115], logprob=-8.875385), TopLogprob(token=' its', bytes=[32, 105, 116, 115], logprob=-9.250385)]),
#    ChatCompletionTokenLogprob(token='itude', bytes=[105, 116, 117, 100, 101], logprob=-1.9361265e-07, top_logprobs=[TopLogprob(token='itude', bytes=[105, 116, 117, 100, 101], logprob=-1.9361265e-07), TopLogprob(token='itudes', bytes=[105, 116, 117, 100, 101, 115], logprob=-16.0), TopLogprob(token='itud', bytes=[105, 116, 117, 100], logprob=-17.625)]),
#    ChatCompletionTokenLogprob(token='**', bytes=[42, 42], logprob=-0.21729769, top_logprobs=[TopLogprob(token='**', bytes=[42, 42], logprob=-0.21729769), TopLogprob(token=' Relationship', bytes=[32, 82, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-1.7172977), TopLogprob(token=' Re', bytes=[32, 82, 101], logprob=-5.2172976)]),
#    ChatCompletionTokenLogprob(token=':', bytes=[58], logprob=-2.2365493e-05, top_logprobs=[TopLogprob(token=':', bytes=[58], logprob=-2.2365493e-05), TopLogprob(token=':\n', bytes=[58, 10], logprob=-10.750022), TopLogprob(token=' -', bytes=[32, 45], logprob=-15.500022)]),
#    ChatCompletionTokenLogprob(token=' While', bytes=[32, 87, 104, 105, 108, 101], logprob=-0.5632867, top_logprobs=[TopLogprob(token=' While', bytes=[32, 87, 104, 105, 108, 101], logprob=-0.5632867), TopLogprob(token=' Conversely', bytes=[32, 67, 111, 110, 118, 101, 114, 115, 101, 108, 121], logprob=-1.5632868), TopLogprob(token=' On', bytes=[32, 79, 110], logprob=-2.5632868)]),
#    ChatCompletionTokenLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.05915516, top_logprobs=[TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.05915516), TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-4.309155), TopLogprob(token=' changes', bytes=[32, 99, 104, 97, 110, 103, 101, 115], logprob=-4.559155)]),
#    ChatCompletionTokenLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-0.0712672, top_logprobs=[TopLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-0.0712672), TopLogprob(token=' changes', bytes=[32, 99, 104, 97, 110, 103, 101, 115], logprob=-3.9462671), TopLogprob(token=' variations', bytes=[32, 118, 97, 114, 105, 97, 116, 105, 111, 110, 115], logprob=-4.071267)]),
#    ChatCompletionTokenLogprob(token=' influence', bytes=[32, 105, 110, 102, 108, 117, 101, 110, 99, 101], logprob=-0.49503568, top_logprobs=[TopLogprob(token=' influence', bytes=[32, 105, 110, 102, 108, 117, 101, 110, 99, 101], logprob=-0.49503568), TopLogprob(token=' affect', bytes=[32, 97, 102, 102, 101, 99, 116], logprob=-1.3700356), TopLogprob(token=' vary', bytes=[32, 118, 97, 114, 121], logprob=-2.4950356)]),
#    ChatCompletionTokenLogprob(token=' weather', bytes=[32, 119, 101, 97, 116, 104, 101, 114], logprob=-0.48152217, top_logprobs=[TopLogprob(token=' weather', bytes=[32, 119, 101, 97, 116, 104, 101, 114], logprob=-0.48152217), TopLogprob(token=' local', bytes=[32, 108, 111, 99, 97, 108], logprob=-1.4815222), TopLogprob(token=' atmospheric', bytes=[32, 97, 116, 109, 111, 115, 112, 104, 101, 114, 105, 99], logprob=-2.981522)]),
#    ChatCompletionTokenLogprob(token=' patterns', bytes=[32, 112, 97, 116, 116, 101, 114, 110, 115], logprob=-0.017571947, top_logprobs=[TopLogprob(token=' patterns', bytes=[32, 112, 97, 116, 116, 101, 114, 110, 115], logprob=-0.017571947), TopLogprob(token=' systems', bytes=[32, 115, 121, 115, 116, 101, 109, 115], logprob=-5.017572), TopLogprob(token=' conditions', bytes=[32, 99, 111, 110, 100, 105, 116, 105, 111, 110, 115], logprob=-5.267572)]),
#    ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.18249568, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.18249568), TopLogprob(token=',', bytes=[44], logprob=-2.0574956), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-3.9324956)]),
#    ChatCompletionTokenLogprob(token=' atmospheric', bytes=[32, 97, 116, 109, 111, 115, 112, 104, 101, 114, 105, 99], logprob=-1.6634464, top_logprobs=[TopLogprob(token=' atmospheric', bytes=[32, 97, 116, 109, 111, 115, 112, 104, 101, 114, 105, 99], logprob=-1.6634464), TopLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-2.0384464), TopLogprob(token=' conditions', bytes=[32, 99, 111, 110, 100, 105, 116, 105, 111, 110, 115], logprob=-2.5384464)]),
#    ChatCompletionTokenLogprob(token=' conditions', bytes=[32, 99, 111, 110, 100, 105, 116, 105, 111, 110, 115], logprob=-0.30427077, top_logprobs=[TopLogprob(token=' conditions', bytes=[32, 99, 111, 110, 100, 105, 116, 105, 111, 110, 115], logprob=-0.30427077), TopLogprob(token=' behavior', bytes=[32, 98, 101, 104, 97, 118, 105, 111, 114], logprob=-2.4292707), TopLogprob(token=' phenomena', bytes=[32, 112, 104, 101, 110, 111, 109, 101, 110, 97], logprob=-2.9292707)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.016312711, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.016312711), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-5.0163126), TopLogprob(token=' at', bytes=[32, 97, 116], logprob=-5.2663126)]),
#    ChatCompletionTokenLogprob(token=' it', bytes=[32, 105, 116], logprob=-0.0443358, top_logprobs=[TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-0.0443358), TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-3.5443358), TopLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-5.044336)]),
#    ChatCompletionTokenLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-0.023414114, top_logprobs=[TopLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-0.023414114), TopLogprob(token=" doesn't", bytes=[32, 100, 111, 101, 115, 110, 39, 116], logprob=-4.398414), TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-5.148414)]),
#    ChatCompletionTokenLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-1.0280384e-06, top_logprobs=[TopLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-1.0280384e-06), TopLogprob(token=' NOT', bytes=[32, 78, 79, 84], logprob=-14.375001), TopLogprob(token=' so', bytes=[32, 115, 111], logprob=-15.625001)]),
#    ChatCompletionTokenLogprob(token=' directly', bytes=[32, 100, 105, 114, 101, 99, 116, 108, 121], logprob=-0.86284155, top_logprobs=[TopLogprob(token=' directly', bytes=[32, 100, 105, 114, 101, 99, 116, 108, 121], logprob=-0.86284155), TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-1.2378416), TopLogprob(token=' have', bytes=[32, 104, 97, 118, 101], logprob=-2.8628416)]),
#    ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.21539547, top_logprobs=[TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-0.21539547), TopLogprob(token=' affect', bytes=[32, 97, 102, 102, 101, 99, 116], logprob=-2.3403955), TopLogprob(token=' influence', bytes=[32, 105, 110, 102, 108, 117, 101, 110, 99, 101], logprob=-3.3403955)]),
#    ChatCompletionTokenLogprob(token=' changes', bytes=[32, 99, 104, 97, 110, 103, 101, 115], logprob=-0.3273374, top_logprobs=[TopLogprob(token=' changes', bytes=[32, 99, 104, 97, 110, 103, 101, 115], logprob=-0.3273374), TopLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-1.7023374), TopLogprob(token=' a', bytes=[32, 97], logprob=-2.8273375)]),
#    ChatCompletionTokenLogprob(token=' in', bytes=[32, 105, 110], logprob=-0.00026228945, top_logprobs=[TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-0.00026228945), TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-8.250262), TopLogprob(token=' or', bytes=[32, 111, 114], logprob=-14.000262)]),
#    ChatCompletionTokenLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-0.000363829, top_logprobs=[TopLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-0.000363829), TopLogprob(token=' physical', bytes=[32, 112, 104, 121, 115, 105, 99, 97, 108], logprob=-8.750364), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-9.375364)]),
#    ChatCompletionTokenLogprob(token='.', bytes=[46], logprob=-0.009202983, top_logprobs=[TopLogprob(token='.', bytes=[46], logprob=-0.009202983), TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-5.384203), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-6.509203)]),
#    ChatCompletionTokenLogprob(token=' Alt', bytes=[32, 65, 108, 116], logprob=-0.69422317, top_logprobs=[TopLogprob(token=' Alt', bytes=[32, 65, 108, 116], logprob=-0.69422317), TopLogprob(token=' Instead', bytes=[32, 73, 110, 115, 116, 101, 97, 100], logprob=-1.8192232), TopLogprob(token=' For', bytes=[32, 70, 111, 114], logprob=-2.9442232)]),
#    ChatCompletionTokenLogprob(token='itude', bytes=[105, 116, 117, 100, 101], logprob=-0.006905641, top_logprobs=[TopLogprob(token='itude', bytes=[105, 116, 117, 100, 101], logprob=-0.006905641), TopLogprob(token='itudes', bytes=[105, 116, 117, 100, 101, 115], logprob=-5.0069056), TopLogprob(token='itud', bytes=[105, 116, 117, 100], logprob=-8.756906)]),
#    ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.016797416, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.016797416), TopLogprob(token=' itself', bytes=[32, 105, 116, 115, 101, 108, 102], logprob=-5.2667975), TopLogprob(token=' remains', bytes=[32, 114, 101, 109, 97, 105, 110, 115], logprob=-5.6417975)]),
#    ChatCompletionTokenLogprob(token=' a', bytes=[32, 97], logprob=-0.091022655, top_logprobs=[TopLogprob(token=' a', bytes=[32, 97], logprob=-0.091022655), TopLogprob(token=' primarily', bytes=[32, 112, 114, 105, 109, 97, 114, 105, 108, 121], logprob=-2.9660227), TopLogprob(token=' determined', bytes=[32, 100, 101, 116, 101, 114, 109, 105, 110, 101, 100], logprob=-4.4660225)]),
#    ChatCompletionTokenLogprob(token=' physical', bytes=[32, 112, 104, 121, 115, 105, 99, 97, 108], logprob=-0.88317055, top_logprobs=[TopLogprob(token=' physical', bytes=[32, 112, 104, 121, 115, 105, 99, 97, 108], logprob=-0.88317055), TopLogprob(token=' geographical', bytes=[32, 103, 101, 111, 103, 114, 97, 112, 104, 105, 99, 97, 108], logprob=-1.5081706), TopLogprob(token=' fixed', bytes=[32, 102, 105, 120, 101, 100], logprob=-1.7581706)]),
#    ChatCompletionTokenLogprob(token=' measurement', bytes=[32, 109, 101, 97, 115, 117, 114, 101, 109, 101, 110, 116], logprob=-0.37788305, top_logprobs=[TopLogprob(token=' measurement', bytes=[32, 109, 101, 97, 115, 117, 114, 101, 109, 101, 110, 116], logprob=-0.37788305), TopLogprob(token=' measure', bytes=[32, 109, 101, 97, 115, 117, 114, 101], logprob=-1.5028831), TopLogprob(token=' characteristic', bytes=[32, 99, 104, 97, 114, 97, 99, 116, 101, 114, 105, 115, 116, 105, 99], logprob=-2.752883)]),
#    ChatCompletionTokenLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.27641398, top_logprobs=[TopLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.27641398), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-2.901414), TopLogprob(token=' above', bytes=[32, 97, 98, 111, 118, 101], logprob=-2.901414)]),
#    ChatCompletionTokenLogprob(token=' height', bytes=[32, 104, 101, 105, 103, 104, 116], logprob=-0.59634566, top_logprobs=[TopLogprob(token=' height', bytes=[32, 104, 101, 105, 103, 104, 116], logprob=-0.59634566), TopLogprob(token=' elevation', bytes=[32, 101, 108, 101, 118, 97, 116, 105, 111, 110], logprob=-1.0963457), TopLogprob(token=' how', bytes=[32, 104, 111, 119], logprob=-3.0963457)]),
#    ChatCompletionTokenLogprob(token=' above', bytes=[32, 97, 98, 111, 118, 101], logprob=-0.041091066, top_logprobs=[TopLogprob(token=' above', bytes=[32, 97, 98, 111, 118, 101], logprob=-0.041091066), TopLogprob(token=',', bytes=[44], logprob=-3.666091), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-5.291091)]),
#    ChatCompletionTokenLogprob(token=' sea', bytes=[32, 115, 101, 97], logprob=-0.06315633, top_logprobs=[TopLogprob(token=' sea', bytes=[32, 115, 101, 97], logprob=-0.06315633), TopLogprob(token=' a', bytes=[32, 97], logprob=-2.8131564), TopLogprob(token=' ground', bytes=[32, 103, 114, 111, 117, 110, 100], logprob=-7.438156)]),
#    ChatCompletionTokenLogprob(token=' level', bytes=[32, 108, 101, 118, 101, 108], logprob=-1.9027791e-05, top_logprobs=[TopLogprob(token=' level', bytes=[32, 108, 101, 118, 101, 108], logprob=-1.9027791e-05), TopLogprob(token='-level', bytes=[45, 108, 101, 118, 101, 108], logprob=-11.500019), TopLogprob(token=' or', bytes=[32, 111, 114], logprob=-12.000019)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.5634702, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.5634702), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.9384702), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-4.3134704)]),
#    ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-1.1858077, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-1.1858077), TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-1.3108077), TopLogprob(token=' while', bytes=[32, 119, 104, 105, 108, 101], logprob=-1.6858077)]),
#    ChatCompletionTokenLogprob(token=' it', bytes=[32, 105, 116], logprob=-1.1456447, top_logprobs=[TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-1.1456447), TopLogprob(token=' while', bytes=[32, 119, 104, 105, 108, 101], logprob=-1.2706447), TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-1.2706447)]),
#    ChatCompletionTokenLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-1.093104, top_logprobs=[TopLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-1.093104), TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-1.218104), TopLogprob(token=' remains', bytes=[32, 114, 101, 109, 97, 105, 110, 115], logprob=-1.218104)]),
#    ChatCompletionTokenLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-3.500108e-05, top_logprobs=[TopLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-3.500108e-05), TopLogprob(token=' influence', bytes=[32, 105, 110, 102, 108, 117, 101, 110, 99, 101], logprob=-11.125035), TopLogprob(token=' affect', bytes=[32, 97, 102, 102, 101, 99, 116], logprob=-11.625035)]),
#    ChatCompletionTokenLogprob(token=' change', bytes=[32, 99, 104, 97, 110, 103, 101], logprob=-0.4760191, top_logprobs=[TopLogprob(token=' change', bytes=[32, 99, 104, 97, 110, 103, 101], logprob=-0.4760191), TopLogprob(token=' vary', bytes=[32, 118, 97, 114, 121], logprob=-1.6010191), TopLogprob(token=' fluctuate', bytes=[32, 102, 108, 117, 99, 116, 117, 97, 116, 101], logprob=-2.1010191)]),
#    ChatCompletionTokenLogprob(token=' based', bytes=[32, 98, 97, 115, 101, 100], logprob=-0.5939921, top_logprobs=[TopLogprob(token=' based', bytes=[32, 98, 97, 115, 101, 100], logprob=-0.5939921), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-1.8439921), TopLogprob(token=' due', bytes=[32, 100, 117, 101], logprob=-1.9689921)]),
#    ChatCompletionTokenLogprob(token=' on', bytes=[32, 111, 110], logprob=-0.050032794, top_logprobs=[TopLogprob(token=' on', bytes=[32, 111, 110], logprob=-0.050032794), TopLogprob(token=' solely', bytes=[32, 115, 111, 108, 101, 108, 121], logprob=-3.1750329), TopLogprob(token=' purely', bytes=[32, 112, 117, 114, 101, 108, 121], logprob=-5.8000326)]),
# ...
#    ChatCompletionTokenLogprob(token=' other', bytes=[32, 111, 116, 104, 101, 114], logprob=-2.220075e-06, top_logprobs=[TopLogprob(token=' other', bytes=[32, 111, 116, 104, 101, 114], logprob=-2.220075e-06), TopLogprob(token=' others', bytes=[32, 111, 116, 104, 101, 114, 115], logprob=-13.875002), TopLogprob(token=' effect', bytes=[32, 101, 102, 102, 101, 99, 116], logprob=-14.375002)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.064253494, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.064253494), TopLogprob(token='.', bytes=[46], logprob=-3.3142536), TopLogprob(token=';', bytes=[59], logprob=-3.6892536)]),
#    ChatCompletionTokenLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.2528104, top_logprobs=[TopLogprob(token=' which', bytes=[32, 119, 104, 105, 99, 104], logprob=-0.2528104), TopLogprob(token=' but', bytes=[32, 98, 117, 116], logprob=-1.5028104), TopLogprob(token=' however', bytes=[32, 104, 111, 119, 101, 118, 101, 114], logprob=-8.8778105)]),
#    ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-1.0427417, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-1.0427417), TopLogprob(token=' contradict', bytes=[32, 99, 111, 110, 116, 114, 97, 100, 105, 99, 116], logprob=-1.9177417), TopLogprob(token=' overlooks', bytes=[32, 111, 118, 101, 114, 108, 111, 111, 107, 115], logprob=-1.9177417)]),
#    ChatCompletionTokenLogprob(token=' incorrect', bytes=[32, 105, 110, 99, 111, 114, 114, 101, 99, 116], logprob=-0.57108766, top_logprobs=[TopLogprob(token=' incorrect', bytes=[32, 105, 110, 99, 111, 114, 114, 101, 99, 116], logprob=-0.57108766), TopLogprob(token=' also', bytes=[32, 97, 108, 115, 111], logprob=-1.5710876), TopLogprob(token=' not', bytes=[32, 110, 111, 116], logprob=-1.9460876)]),
#    ChatCompletionTokenLogprob(token=' because', bytes=[32, 98, 101, 99, 97, 117, 115, 101], logprob=-1.1350243, top_logprobs=[TopLogprob(token=' because', bytes=[32, 98, 101, 99, 97, 117, 115, 101], logprob=-1.1350243), TopLogprob(token=' since', bytes=[32, 115, 105, 110, 99, 101], logprob=-1.1350243), TopLogprob(token=' as', bytes=[32, 97, 115], logprob=-1.6350243)]),
#    ChatCompletionTokenLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-1.0791471, top_logprobs=[TopLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-1.0791471), TopLogprob(token=' we', bytes=[32, 119, 101], logprob=-1.2041471), TopLogprob(token=' there', bytes=[32, 116, 104, 101, 114, 101], logprob=-1.2041471)]),
#    ChatCompletionTokenLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-0.41443253, top_logprobs=[TopLogprob(token=' does', bytes=[32, 100, 111, 101, 115], logprob=-0.41443253), TopLogprob(token=' clearly', bytes=[32, 99, 108, 101, 97, 114, 108, 121], logprob=-2.2894325), TopLogprob(token=' indeed', bytes=[32, 105, 110, 100, 101, 101, 100], logprob=-2.4144325)]),
#    ChatCompletionTokenLogprob(token=' indeed', bytes=[32, 105, 110, 100, 101, 101, 100], logprob=-0.8028694, top_logprobs=[TopLogprob(token=' indeed', bytes=[32, 105, 110, 100, 101, 101, 100], logprob=-0.8028694), TopLogprob(token=' have', bytes=[32, 104, 97, 118, 101], logprob=-1.6778693), TopLogprob(token=' affect', bytes=[32, 97, 102, 102, 101, 99, 116], logprob=-1.8028693)]),
#    ChatCompletionTokenLogprob(token=' affect', bytes=[32, 97, 102, 102, 101, 99, 116], logprob=-0.6863759, top_logprobs=[TopLogprob(token=' affect', bytes=[32, 97, 102, 102, 101, 99, 116], logprob=-0.6863759), TopLogprob(token=' influence', bytes=[32, 105, 110, 102, 108, 117, 101, 110, 99, 101], logprob=-1.1863759), TopLogprob(token=' have', bytes=[32, 104, 97, 118, 101], logprob=-1.9363759)]),
#    ChatCompletionTokenLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.00023309923, top_logprobs=[TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.00023309923), TopLogprob(token=' temperatures', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101, 115], logprob=-9.000233), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-9.250233)]),
#    ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.0050721066, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.0050721066), TopLogprob(token='.', bytes=[46], logprob=-6.630072), TopLogprob(token=' significantly', bytes=[32, 115, 105, 103, 110, 105, 102, 105, 99, 97, 110, 116, 108, 121], logprob=-6.755072)]),
#    ChatCompletionTokenLogprob(token='Based', bytes=[66, 97, 115, 101, 100], logprob=-0.79715157, top_logprobs=[TopLogprob(token='Based', bytes=[66, 97, 115, 101, 100], logprob=-0.79715157), TopLogprob(token='Given', bytes=[71, 105, 118, 101, 110], logprob=-0.79715157), TopLogprob(token='Considering', bytes=[67, 111, 110, 115, 105, 100, 101, 114, 105, 110, 103], logprob=-3.0471516)]),
#    ChatCompletionTokenLogprob(token=' on', bytes=[32, 111, 110], logprob=-7.088138e-05, top_logprobs=[TopLogprob(token=' on', bytes=[32, 111, 110], logprob=-7.088138e-05), TopLogprob(token=' upon', bytes=[32, 117, 112, 111, 110], logprob=-9.750071), TopLogprob(token=' solely', bytes=[32, 115, 111, 108, 101, 108, 121], logprob=-12.000071)]),
#    ChatCompletionTokenLogprob(token=' this', bytes=[32, 116, 104, 105, 115], logprob=-0.22754838, top_logprobs=[TopLogprob(token=' this', bytes=[32, 116, 104, 105, 115], logprob=-0.22754838), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-1.8525484), TopLogprob(token=' these', bytes=[32, 116, 104, 101, 115, 101], logprob=-3.1025484)]),
#    ChatCompletionTokenLogprob(token=' reasoning', bytes=[32, 114, 101, 97, 115, 111, 110, 105, 110, 103], logprob=-0.20876296, top_logprobs=[TopLogprob(token=' reasoning', bytes=[32, 114, 101, 97, 115, 111, 110, 105, 110, 103], logprob=-0.20876296), TopLogprob(token=' analysis', bytes=[32, 97, 110, 97, 108, 121, 115, 105, 115], logprob=-1.833763), TopLogprob(token=' understanding', bytes=[32, 117, 110, 100, 101, 114, 115, 116, 97, 110, 100, 105, 110, 103], logprob=-3.708763)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.003883558, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.003883558), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-5.7538834), TopLogprob(token=':\n', bytes=[58, 10], logprob=-7.5038834)]),
#    ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.2348586, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.2348586), TopLogprob(token=' option', bytes=[32, 111, 112, 116, 105, 111, 110], logprob=-1.9848586), TopLogprob(token=' it', bytes=[32, 105, 116], logprob=-3.1098585)]),
#    ChatCompletionTokenLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-0.37613425, top_logprobs=[TopLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-0.37613425), TopLogprob(token=' more', bytes=[32, 109, 111, 114, 101], logprob=-1.7511343), TopLogprob(token=' correct', bytes=[32, 99, 111, 114, 114, 101, 99, 116], logprob=-3.1261342)]),
#    ChatCompletionTokenLogprob(token=' accurate', bytes=[32, 97, 99, 99, 117, 114, 97, 116, 101], logprob=-0.7591919, top_logprobs=[TopLogprob(token=' accurate', bytes=[32, 97, 99, 99, 117, 114, 97, 116, 101], logprob=-0.7591919), TopLogprob(token=' likely', bytes=[32, 108, 105, 107, 101, 108, 121], logprob=-1.0091919), TopLogprob(token=' plausible', bytes=[32, 112, 108, 97, 117, 115, 105, 98, 108, 101], logprob=-2.884192)]),
#    ChatCompletionTokenLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-1.4237446, top_logprobs=[TopLogprob(token=' cause', bytes=[32, 99, 97, 117, 115, 101], logprob=-1.4237446), TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-1.6737446), TopLogprob(token=' statement', bytes=[32, 115, 116, 97, 116, 101, 109, 101, 110, 116], logprob=-1.6737446)]),
#    ChatCompletionTokenLogprob(token='-and', bytes=[45, 97, 110, 100], logprob=-0.0016855322, top_logprobs=[TopLogprob(token='-and', bytes=[45, 97, 110, 100], logprob=-0.0016855322), TopLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-6.5016856), TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-8.626685)]),
#    ChatCompletionTokenLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-3.5313153e-06, top_logprobs=[TopLogprob(token='-effect', bytes=[45, 101, 102, 102, 101, 99, 116], logprob=-3.5313153e-06), TopLogprob(token='-effects', bytes=[45, 101, 102, 102, 101, 99, 116, 115], logprob=-13.125004), TopLogprob(token=' effect', bytes=[32, 101, 102, 102, 101, 99, 116], logprob=-13.750004)]),
#    ChatCompletionTokenLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.0018894952, top_logprobs=[TopLogprob(token=' relationship', bytes=[32, 114, 101, 108, 97, 116, 105, 111, 110, 115, 104, 105, 112], logprob=-0.0018894952), TopLogprob(token=' statement', bytes=[32, 115, 116, 97, 116, 101, 109, 101, 110, 116], logprob=-6.8768897), TopLogprob(token='-', bytes=[45], logprob=-7.6268897)]),
#    ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.021721099, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.021721099), TopLogprob(token=' here', bytes=[32, 104, 101, 114, 101], logprob=-4.646721), TopLogprob(token=' between', bytes=[32, 98, 101, 116, 119, 101, 101, 110], logprob=-5.521721)]),
#    ChatCompletionTokenLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-0.062411394, top_logprobs=[TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-0.062411394), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-3.6874113), TopLogprob(token=' option', bytes=[32, 111, 112, 116, 105, 111, 110], logprob=-4.3124113)]),
#    ChatCompletionTokenLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-0.029174764, top_logprobs=[TopLogprob(token=' altitude', bytes=[32, 97, 108, 116, 105, 116, 117, 100, 101], logprob=-0.029174764), TopLogprob(token=' **', bytes=[32, 42, 42], logprob=-4.154175), TopLogprob(token=' "', bytes=[32, 34], logprob=-4.654175)]),
#    ChatCompletionTokenLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-0.122316934, top_logprobs=[TopLogprob(token=' causes', bytes=[32, 99, 97, 117, 115, 101, 115], logprob=-0.122316934), TopLogprob(token=' affects', bytes=[32, 97, 102, 102, 101, 99, 116, 115], logprob=-2.4973168), TopLogprob(token=' influences', bytes=[32, 105, 110, 102, 108, 117, 101, 110, 99, 101, 115], logprob=-3.7473168)]),
#    ChatCompletionTokenLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.009192703, top_logprobs=[TopLogprob(token=' temperature', bytes=[32, 116, 101, 109, 112, 101, 114, 97, 116, 117, 114, 101], logprob=-0.009192703), TopLogprob(token=' changes', bytes=[32, 99, 104, 97, 110, 103, 101, 115], logprob=-4.7591925), TopLogprob(token=' a', bytes=[32, 97], logprob=-8.009192)]),
#    ChatCompletionTokenLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.7042877, top_logprobs=[TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-0.7042877), TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-1.3292878), TopLogprob(token=' changes', bytes=[32, 99, 104, 97, 110, 103, 101, 115], logprob=-2.2042878)]),
#    ChatCompletionTokenLogprob(token='Thus', bytes=[84, 104, 117, 115], logprob=-0.88926756, top_logprobs=[TopLogprob(token='Thus', bytes=[84, 104, 117, 115], logprob=-0.88926756), TopLogprob(token='Final', bytes=[70, 105, 110, 97, 108], logprob=-1.0142676), TopLogprob(token='Therefore', bytes=[84, 104, 101, 114, 101, 102, 111, 114, 101], logprob=-1.7642676)]),
#    ChatCompletionTokenLogprob(token=',', bytes=[44], logprob=-0.0011907028, top_logprobs=[TopLogprob(token=',', bytes=[44], logprob=-0.0011907028), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-6.8761907), TopLogprob(token=' my', bytes=[32, 109, 121], logprob=-8.876191)]),
#    ChatCompletionTokenLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.33286285, top_logprobs=[TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-0.33286285), TopLogprob(token=' my', bytes=[32, 109, 121], logprob=-1.3328629), TopLogprob(token=' I', bytes=[32, 73], logprob=-3.9578629)]),
#    ChatCompletionTokenLogprob(token=' final', bytes=[32, 102, 105, 110, 97, 108], logprob=-0.37509876, top_logprobs=[TopLogprob(token=' final', bytes=[32, 102, 105, 110, 97, 108], logprob=-0.37509876), TopLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-1.7500987), TopLogprob(token=' most', bytes=[32, 109, 111, 115, 116], logprob=-3.1250987)]),
#    ChatCompletionTokenLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-0.003228933, top_logprobs=[TopLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-0.003228933), TopLogprob(token=' decision', bytes=[32, 100, 101, 99, 105, 115, 105, 111, 110], logprob=-6.003229), TopLogprob(token=' choice', bytes=[32, 99, 104, 111, 105, 99, 101], logprob=-8.128229)]),
#    ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.0061016814, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.0061016814), TopLogprob(token=' will', bytes=[32, 119, 105, 108, 108], logprob=-6.6311016), TopLogprob(token=' would', bytes=[32, 119, 111, 117, 108, 100], logprob=-6.8811016)]),
#    ChatCompletionTokenLogprob(token=' <', bytes=[32, 60], logprob=-0.06772006, top_logprobs=[TopLogprob(token=' <', bytes=[32, 60], logprob=-0.06772006), TopLogprob(token=':\n\n', bytes=[58, 10, 10], logprob=-3.4427202), TopLogprob(token=':', bytes=[58], logprob=-3.9427202)]),
#    ChatCompletionTokenLogprob(token='answer', bytes=[97, 110, 115, 119, 101, 114], logprob=-3.1281633e-07, top_logprobs=[TopLogprob(token='answer', bytes=[97, 110, 115, 119, 101, 114], logprob=-3.1281633e-07), TopLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-15.75), TopLogprob(token='A', bytes=[65], logprob=-16.5)]),
#    ChatCompletionTokenLogprob(token='>B', bytes=[62, 66], logprob=-3.7146747e-05, top_logprobs=[TopLogprob(token='>B', bytes=[62, 66], logprob=-3.7146747e-05), TopLogprob(token='>', bytes=[62], logprob=-10.250037), TopLogprob(token='>C', bytes=[62, 67], logprob=-13.750037)]),
#    ChatCompletionTokenLogprob(token='</', bytes=[60, 47], logprob=0.0, top_logprobs=[TopLogprob(token='</', bytes=[60, 47], logprob=0.0), TopLogprob(token='<', bytes=[60], logprob=-17.75), TopLogprob(token=' </', bytes=[32, 60, 47], logprob=-17.875)]),
#    ChatCompletionTokenLogprob(token='answer', bytes=[97, 110, 115, 119, 101, 114], logprob=0.0, top_logprobs=[TopLogprob(token='answer', bytes=[97, 110, 115, 119, 101, 114], logprob=0.0), TopLogprob(token=' answer', bytes=[32, 97, 110, 115, 119, 101, 114], logprob=-18.375), TopLogprob(token='answers', bytes=[97, 110, 115, 119, 101, 114, 115], logprob=-21.375)]),
#    ChatCompletionTokenLogprob(token='>', bytes=[62], logprob=-0.2505355, top_logprobs=[TopLogprob(token='>', bytes=[62], logprob=-0.2505355), TopLogprob(token='>,', bytes=[62, 44], logprob=-1.6255355), TopLogprob(token='>.', bytes=[62, 46], logprob=-3.7505355)]),
#    ChatCompletionTokenLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.09085929, top_logprobs=[TopLogprob(token=' and', bytes=[32, 97, 110, 100], logprob=-0.09085929), TopLogprob(token='.\n\n', bytes=[46, 10, 10], logprob=-2.5908592), TopLogprob(token=' with', bytes=[32, 119, 105, 116, 104], logprob=-4.4658594)])],
#   'answer_token_logprob': -3.7146747e-05,
#   'answer_choice_logprobs': {},
#   'answer_tokens_logprobs': [{'token': '>B', 'logprob': -3.7146747e-05}]}}

# %%
llm_output
# Out:
# {('pair0000',
#   0.3,
#   1): {'llm_ab': (1,
#    1.0,
#    ['T. J. McGregor, "Effects of Altitude on Temperature Variation in Mountain Areas," 2018',
#     'J. K. Halverson, "The Impact of Altitude on Climate Zones and Temperature Patterns," 2020',
#     'L. R. Smith and M. T. Jones, "Altitude and Its Relationship with Temperature in Diverse Ecosystems," 2021']), 'llm_ba': (0,
#    0.9,
#    ['Betts, A. K., "The impact of temperature on the vertical profile of humidity in the atmosphere", 2000',
#     'Stull, R. B., "Meteorology for Scientists and Engineers", 2017',
#     'Barry, R. G., & Choudhury, J. R., "Climate Change and Mountain Regions: A Review", 2009'])}}

# %% [markdown]
# ### Hallbayes

# %%
# Create hallbayes backend using the existing Azure OpenAI client
# We need to bypass the default OpenAI API key requirement
import os
from hallbayes import OpenAIBackend, OpenAIItem, OpenAIPlanner
temp_api_key = os.environ.get("PORTKEY_AZURE_US_API_KEY")

# Create the backend with our Azure model and then replace the client
hallbayes_backend = OpenAIBackend(model=azure_model, api_key=temp_api_key)

azure_openai_client = OpenAI(base_url=us_base_url,
            api_key=os.environ["PORTKEY_AZURE_US_API_KEY"],
            default_headers=portkey_headers)


# Replace the default client with our configured Azure OpenAI client 
hallbayes_backend.client = azure_openai_client

# %%
planner = OpenAIPlanner(hallbayes_backend, temperature=0.3)

# %%
# HallBayes validation function adapted for llm_output structure
def validate_llm_output_with_hallbayes(llm_output, saved_pairs_info, planner, method="with_evidence", threshold=0.10, n_runs=1):
    """
    Validates causal relationships from llm_output using hallbayes with hallucination risk assessment
    
    Args:
        llm_output: dict with keys (pair_id, temperature, run) containing llm_ab and llm_ba results
        saved_pairs_info: dict with pair information (var1, var2, ground_truth)
        planner: configured hallbayes planner
        method: "closed_book" or "with_evidence" 
        threshold: max acceptable hallucination risk
        n_runs: number of validation runs per relationship (for consistency)
    
    Returns:
        dict: hallucination risk results for each query
    
    Note: HallBayes internally generates multiple samples (n_samples=3, m=4) per validation
    to ensure robust risk estimation. This is expected behavior.
    """
    print(f"Calculating hallucination risk using {method.upper()} method")
    print(f"Threshold: {threshold:.1%}")
    print(f"Validation runs per relationship: {n_runs}")
    print(f"Total pairs to process: {len(llm_output)}")
    print("Note: HallBayes will generate multiple internal samples per validation")
    print("=" * 60)
    
    hallucination_risks = {}
    
    # Process each pair and run combination
    for (pair_id, temp, run_num), output in llm_output.items():
        print(f"\nProcessing {pair_id}, run {run_num}")
        
        pair_info = saved_pairs_info[pair_id]
        var1, var2 = pair_info['var1'], pair_info['var2']
        
        # Process A→B direction
        ab_result = output['llm_ab']
        ab_response = ab_result.get('result', [None, None, ""])[2]  # Get the LLM response text
        ab_evidence = ab_result.get('sources_content', "")  # Get retrieved evidence
        
        # Process B→A direction  
        ba_result = output['llm_ba']
        ba_response = ba_result.get('result', [None, None, ""])[2]  # Get the LLM response text
        ba_evidence = ba_result.get('sources_content', "")  # Get retrieved evidence
        
        # Validate A→B
        ab_risk = _calculate_single_hallucination_risk(
            var1, var2, ab_response, ab_evidence, planner, method, threshold, n_runs
        )
        
        # Validate B→A
        ba_risk = _calculate_single_hallucination_risk(
            var2, var1, ba_response, ba_evidence, planner, method, threshold, n_runs
        )
        
        # Store results
        key = (pair_id, temp, run_num)
        hallucination_risks[key] = {
            'ab_hallucination_risk': ab_risk['avg_risk'],
            'ab_is_valid': ab_risk['final_valid'],
            'ba_hallucination_risk': ba_risk['avg_risk'], 
            'ba_is_valid': ba_risk['final_valid']
        }
        
        print(f"  A→B: Risk={ab_risk['avg_risk']:.1%}, Valid={ab_risk['final_valid']}")
        print(f"  B→A: Risk={ba_risk['avg_risk']:.1%}, Valid={ba_risk['final_valid']}")
    
    return hallucination_risks


def _calculate_single_hallucination_risk(cause, effect, response, evidence, planner, method, threshold, n_runs):
    """
    Calculate hallucination risk for a single causal relationship query
    
    Note: HallBayes internally uses n_samples=3, m=4 to generate multiple samples
    for robust risk estimation. This is expected behavior.
    """
    # Prepare prompt based on method
    if method == "closed_book":
        prompt = f"""
        Causal Knowledge Assessment:
        
        Claim: "{cause}" causes "{effect}"
        Response: {response}
        
        Question: Based on established scientific knowledge, 
        is this causal claim and response scientifically accurate?
        
        Answer: Yes/No with brief justification.
        """
    elif method == "with_evidence":
        prompt = f"""
        Evidence-Based Assessment:
        
        Retrieved Evidence: {evidence}
        
        Claim: "{cause}" causes "{effect}"
        LLM Response: {response}
        
        Question: Based on the provided evidence and your knowledge, 
        is this causal relationship claim and response valid and well-supported?
        
        Answer: Yes/No referencing the evidence and additional knowledge.
        """
    else:
        raise ValueError(f"Unknown method: {method}")
    
    # Run multiple validations for consistency
    run_results = []
    valid_count = 0
    
    print(f"    Running HallBayes validation for: {cause} -> {effect}")
    
    for run in range(n_runs):
        try:
            # HallBayes uses n_samples=3, m=4 internally for robust risk estimation
            # This generates multiple samples per validation run
            item = OpenAIItem(prompt=prompt, n_samples=3, m=4, skeleton_policy=method)
            print(f"      Validation run {run + 1}/{n_runs}: Generating HallBayes samples...")
            metrics = planner.run([item], h_star=threshold, isr_threshold=1.0)
            
            if metrics:
                metric = metrics[0]
                is_valid = metric.decision_answer
                risk = metric.roh_bound
                
                if is_valid:
                    valid_count += 1
                
                run_results.append({
                    'valid': is_valid,
                    'risk': risk,
                    'run': run + 1
                })
                print(f"      Run {run + 1} result: Valid={is_valid}, Risk={risk:.1%}")
            else:
                run_results.append({'valid': False, 'risk': 1.0, 'run': run + 1, 'error': 'No metrics'})
                print(f"      Run {run + 1} failed: No metrics returned")
                
        except Exception as e:
            run_results.append({'valid': False, 'risk': 1.0, 'run': run + 1, 'error': str(e)})
            print(f"      Run {run + 1} error: {str(e)}")
    
    # Calculate final decision and average risk
    avg_risk = sum(r.get('risk', 1.0) for r in run_results) / len(run_results) if run_results else 1.0
    
    # Determine final validation (majority vote)
    final_valid = valid_count > (n_runs / 2) if n_runs > 0 else False
    
    return {
        'final_valid': final_valid,
        'avg_risk': avg_risk,
        'valid_runs': valid_count,
        'total_runs': n_runs,
        'runs': run_results
    }


# Calculate hallucination risks for all queries
print("Calculating hallucination risks for all A→B and B→A queries...")
hallucination_results = validate_llm_output_with_hallbayes(
    llm_output, saved_pairs_info, planner, 
    method="with_evidence", threshold=0.10, n_runs=1
)
# Out:
# Calculating hallucination risks for all A→B and B→A queries...
# Calculating hallucination risk using WITH_EVIDENCE method
# Threshold: 10.0%
# Validation runs per relationship: 1
# Total pairs to process: 1
# Note: HallBayes will generate multiple internal samples per validation
# ============================================================
#
# Processing pair0000, run 1
#     Running HallBayes validation for:  Altitude ->  Temperature
#       Validation run 1/1: Generating HallBayes samples...
#       Run 1 result: Valid=True, Risk=0.0%
#     Running HallBayes validation for:  Temperature ->  Altitude
#       Validation run 1/1: Generating HallBayes samples...
#       Run 1 result: Valid=True, Risk=0.0%
#     Running HallBayes validation for:  Temperature ->  Altitude
#       Validation run 1/1: Generating HallBayes samples...
#       Run 1 result: Valid=True, Risk=0.0%
#   A→B: Risk=0.0%, Valid=True
#   B→A: Risk=0.0%, Valid=True
#       Run 1 result: Valid=True, Risk=0.0%
#   A→B: Risk=0.0%, Valid=True
#   B→A: Risk=0.0%, Valid=True

# %% [markdown]
# ### Export results

# %%
# my code initial
# results : Dict = {}

# for id in saved_pairs_info:

#     av_correct_ab = 0
#     av_correct_ba = 0

#     for i in range(num_runs):

#         if llm_output[(id, 0.3, i+1)]['llm_ab'] == 1 and saved_pairs_info[id]['ground_truth'] == " R":
#             av_correct_ab += 1
#         elif llm_output[(id, 0.3, i+1)]['llm_ab'] == 0 and saved_pairs_info[id]['ground_truth'] == " L":
#             av_correct_ab += 1

#         if llm_output[(id, 0.3, i+1)]['llm_ba'] == 1 and saved_pairs_info[id]['ground_truth'] == " L":
#             av_correct_ba += 1
#         elif llm_output[(id, 0.3, i+1)]['llm_ba'] == 0 and saved_pairs_info[id]['ground_truth'] == " R":
#             av_correct_ba += 1

#     av_correct_ab /= num_runs
#     av_correct_ba /= num_runs

#     temp : Dict = {}

#     temp['PairID'] = id
#     temp['CorrectACauseB'] = av_correct_ab
#     temp['CorrectBCauseA'] = av_correct_ba
#     temp['VarA'] = saved_pairs_info[id]['var1']
#     temp['VarB'] = saved_pairs_info[id]['var2']
#     temp['GroundTruth'] = saved_pairs_info[id]['ground_truth']

#     results[id] = temp
#     print(results[id])
# Out:
# {'PairID': 'pair0000', 'CorrectACauseB': 1.0, 'CorrectBCauseA': 1.0, 'VarA': ' Altitude', 'VarB': ' Temperature', 'GroundTruth': ' R'}
# {'PairID': 'pair0001', 'CorrectACauseB': 1.0, 'CorrectBCauseA': 1.0, 'VarA': ' Altitude', 'VarB': ' Precipitation', 'GroundTruth': ' R'}
# {'PairID': 'pair0002', 'CorrectACauseB': 1.0, 'CorrectBCauseA': 1.0, 'VarA': ' Longitude', 'VarB': ' Temperature', 'GroundTruth': ' R'}

# %%
results : Dict = {}

for id in saved_pairs_info:

    av_correct_ab = 0
    av_correct_ba = 0
    
    # Lists to collect confidence scores and references across runs
    confidence_scores_ab = []
    confidence_scores_ba = []
    references_ab = []
    references_ba = []

    for i in range(num_runs):
        # Extract relationship, confidence, and other data from dictionary
        ab_result = llm_output[(id, 0.3, i+1)]['llm_ab']
        ba_result = llm_output[(id, 0.3, i+1)]['llm_ba']
        
        # Get data from result dictionary
        ab_answer = ab_result.get('answer', '')
        ba_answer = ba_result.get('answer', '')
        ab_confidence = ab_result.get('confidence_score')
        ba_confidence = ba_result.get('confidence_score')
        
        # Store confidence scores (only if not None)
        if ab_confidence is not None:
            confidence_scores_ab.append(ab_confidence)
        if ba_confidence is not None:
            confidence_scores_ba.append(ba_confidence)
            
        # For baseline method, we don't have references, so use empty lists
        references_ab.extend([])
        references_ba.extend([])

        # Convert answer letters to relationship values for correctness checking
        # A means var1 -> var2 (relationship = 1), B means var2 -> var1 (relationship = 0), C means no relationship
        ab_relationship = 1 if ab_answer == "A" else 0 if ab_answer == "B" else None
        ba_relationship = 1 if ba_answer == "A" else 0 if ba_answer == "B" else None

        # Check correctness using the relationship value
        if ab_relationship == 1 and saved_pairs_info[id]['ground_truth'] == " R":
            av_correct_ab += 1
        elif ab_relationship == 0 and saved_pairs_info[id]['ground_truth'] == " L":
            av_correct_ab += 1

        if ba_relationship == 1 and saved_pairs_info[id]['ground_truth'] == " L":
            av_correct_ba += 1
        elif ba_relationship == 0 and saved_pairs_info[id]['ground_truth'] == " R":
            av_correct_ba += 1

    av_correct_ab /= num_runs
    av_correct_ba /= num_runs
    
    # Calculate average confidence scores
    avg_confidence_ab = sum(confidence_scores_ab) / len(confidence_scores_ab) if confidence_scores_ab else None
    avg_confidence_ba = sum(confidence_scores_ba) / len(confidence_scores_ba) if confidence_scores_ba else None

    temp : Dict = {}

    temp['PairID'] = id
    temp['CorrectACauseB'] = av_correct_ab
    temp['CorrectBCauseA'] = av_correct_ba
    temp['VarA'] = saved_pairs_info[id]['var1']
    temp['VarB'] = saved_pairs_info[id]['var2']
    temp['GroundTruth'] = saved_pairs_info[id]['ground_truth']
    temp['ConfidenceAB'] = avg_confidence_ab
    temp['ConfidenceBA'] = avg_confidence_ba
    temp['ReferencesAB'] = references_ab
    temp['ReferencesBA'] = references_ba

    results[id] = temp
    print(results[id])
# Out:
# {'PairID': 'pair0000', 'CorrectACauseB': 1.0, 'CorrectBCauseA': 1.0, 'VarA': ' Altitude', 'VarB': ' Temperature', 'GroundTruth': ' R', 'ConfidenceAB': 0.95, 'ConfidenceBA': None, 'ReferencesAB': [], 'ReferencesBA': []}

# %%
# Calculate accuracy metrics
accuracy_results = {}

total_pairs = len(results)
sum_ab_accuracy = 0
sum_ba_accuracy = 0
sum_joint_accuracy = 0
sum_ab_confidence = 0
sum_ba_confidence = 0
count_ab_confidence = 0
count_ba_confidence = 0


for pair_id, result in results.items():
    # Individual accuracies per pair (these are already averages from multiple runs, can be decimal)
    correct_ab = result['CorrectACauseB']  # This is the mean accuracy (0.0 to 1.0, can be decimal)
    correct_ba = result['CorrectBCauseA']  # This is the mean accuracy (0.0 to 1.0, can be decimal)
    
    # Get confidence scores
    confidence_ab = result.get('ConfidenceAB')
    confidence_ba = result.get('ConfidenceBA')
    
    # Joint accuracy: average of both directions (more nuanced approach)
    joint_accuracy = (correct_ab + correct_ba) / 2.0
    
    # Sum for overall statistics (averaging across all pairs)
    sum_ab_accuracy += correct_ab
    sum_ba_accuracy += correct_ba
    sum_joint_accuracy += joint_accuracy
    
    # Sum confidence scores for overall statistics
    if confidence_ab is not None:
        sum_ab_confidence += confidence_ab
        count_ab_confidence += 1
    if confidence_ba is not None:
        sum_ba_confidence += confidence_ba
        count_ba_confidence += 1
    
    # STORING INDIVIDUAL
    # Store individual pair results (only decimal values, no redundant percentages)
    accuracy_results[pair_id] = {
        'PairID': pair_id,
        'VarA': result['VarA'],
        'VarB': result['VarB'],
        'GroundTruth': result['GroundTruth'],
        'AccuracyAB': correct_ab,  # Decimal value (0.0 to 1.0)
        'AccuracyBA': correct_ba,  # Decimal value (0.0 to 1.0)
        'JointAccuracy': joint_accuracy,  # Average of both directions
        'ConfidenceAB': confidence_ab,  # Confidence score for A->B
        'ConfidenceBA': confidence_ba   # Confidence score for B->A
    }
    
    print(f"Pair {pair_id}: {result['VarA']} -> {result['VarB']}")
    print(f"  Ground Truth: {result['GroundTruth']}")
    print(f"  A→B Accuracy: {correct_ab:.3f}, Confidence: {f'{confidence_ab:.3f}' if confidence_ab is not None else 'N/A'}")
    print(f"  B→A Accuracy: {correct_ba:.3f}, Confidence: {f'{confidence_ba:.3f}' if confidence_ba is not None else 'N/A'}")
    print(f"  Joint Accuracy (avg): {joint_accuracy:.3f}")
    print()


# Overall accuracy statistics (averages across all pairs)
overall_ab_accuracy = sum_ab_accuracy / total_pairs
overall_ba_accuracy = sum_ba_accuracy / total_pairs
overall_joint_accuracy = sum_joint_accuracy / total_pairs

# Overall confidence statistics
overall_ab_confidence = sum_ab_confidence / count_ab_confidence if count_ab_confidence > 0 else None
overall_ba_confidence = sum_ba_confidence / count_ba_confidence if count_ba_confidence > 0 else None

print("=== OVERALL ACCURACY STATISTICS ===")
print(f"Total pairs processed: {total_pairs}")
print(f"\nMEAN ACCURACIES (across all pairs):")
print(f"A→B Mean Accuracy: {overall_ab_accuracy:.3f}")
print(f"B→A Mean Accuracy: {overall_ba_accuracy:.3f}")
print(f"Joint Mean Accuracy: {overall_joint_accuracy:.3f}")
print(f"\nMEAN CONFIDENCE SCORES:")
print(f"A→B Mean Confidence: {f'{overall_ab_confidence:.3f}' if overall_ab_confidence is not None else 'N/A'}")
print(f"B→A Mean Confidence: {f'{overall_ba_confidence:.3f}' if overall_ba_confidence is not None else 'N/A'}")
print(f"\nLATENCY METRICS:")
print(f"Average time per pair (both directions): {avg_latency_per_pair:.2f}s")
print(f"Average time per query: {avg_latency_per_run:.2f}s")

# Summary statistics (only valuable info, no redundant percentages)
accuracy_summary = {
    'total_pairs': total_pairs,
    'ab_mean_accuracy': overall_ab_accuracy,
    'ba_mean_accuracy': overall_ba_accuracy,
    'joint_mean_accuracy': overall_joint_accuracy,
    'ab_mean_confidence': overall_ab_confidence,
    'ba_mean_confidence': overall_ba_confidence,
    'avg_latency_per_pair_seconds': round(avg_latency_per_pair, 2),
    'avg_latency_per_query_seconds': round(avg_latency_per_run, 2),
    'total_execution_time_seconds': round(total_time, 2)
}
# Out:
# Pair pair0000:  Altitude ->  Temperature
#   Ground Truth:  R
#   A→B Accuracy: 1.000, Confidence: 0.950
#   B→A Accuracy: 1.000, Confidence: N/A
#   Joint Accuracy (avg): 1.000
#
# === OVERALL ACCURACY STATISTICS ===
# Total pairs processed: 1
#
# MEAN ACCURACIES (across all pairs):
# A→B Mean Accuracy: 1.000
# B→A Mean Accuracy: 1.000
# Joint Mean Accuracy: 1.000
#
# MEAN CONFIDENCE SCORES:
# A→B Mean Confidence: 0.950
# B→A Mean Confidence: N/A
#
# LATENCY METRICS:
# Average time per pair (both directions): 16.78s
# Average time per query: 8.39s

# %%
# Save accuracy results to CSV
import csv

# CSV file for detailed accuracy results (now includes confidence scores)
accuracy_csv_file = "alba_accuracy_results.csv"

# Define headers for detailed accuracy results (includes confidence)
accuracy_header = [
    "PairID", "VarA", "VarB", "GroundTruth", 
    "AccuracyAB", "AccuracyBA", "JointAccuracy",
    "ConfidenceAB", "ConfidenceBA"
]

# Write detailed accuracy results
with open(accuracy_csv_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=accuracy_header)
    writer.writeheader()
    for pair_id, values in accuracy_results.items():
        writer.writerow(values)

print(f"Detailed accuracy CSV file '{accuracy_csv_file}' has been created.")

# CSV file for summary statistics
summary_csv_file = "alba_accuracy_summary.csv"

# Write summary statistics
with open(summary_csv_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=list(accuracy_summary.keys()))
    writer.writeheader()
    writer.writerow(accuracy_summary)

print(f"Summary accuracy CSV file '{summary_csv_file}' has been created.")

# Display final summary table (clean format with confidence)
print("\n=== FINAL SUMMARY TABLE ===")
print(f"{'Metric':<25} {'Mean Accuracy':<15} {'Mean Confidence':<18}")
print("-" * 60)
ab_conf_str = f"{accuracy_summary['ab_mean_confidence']:.3f}" if accuracy_summary['ab_mean_confidence'] is not None else 'N/A'
ba_conf_str = f"{accuracy_summary['ba_mean_confidence']:.3f}" if accuracy_summary['ba_mean_confidence'] is not None else 'N/A'
print(f"{'A→B':<25} {accuracy_summary['ab_mean_accuracy']:<15.3f} {ab_conf_str:<18}")
print(f"{'B→A':<25} {accuracy_summary['ba_mean_accuracy']:<15.3f} {ba_conf_str:<18}")
print(f"{'Joint Accuracy':<25} {accuracy_summary['joint_mean_accuracy']:<15.3f} {'N/A':<18}")
print(f"{'Total Pairs':<25} {accuracy_summary['total_pairs']:<15} {'N/A':<18}")
# Out:
# Detailed accuracy CSV file 'alba_accuracy_results.csv' has been created.
# Summary accuracy CSV file 'alba_accuracy_summary.csv' has been created.
#
# === FINAL SUMMARY TABLE ===
# Metric                    Mean Accuracy   Mean Confidence    Perfect Count   Perfect Rate
# ------------------------------------------------------------------------------------------
# A→B                       1.000           0.917              3               1.000
# B→A                       1.000           0.850              3               1.000
# Joint Accuracy            1.000           N/A                3               1.000
# Total Pairs               3               N/A                N/A             1.000

# %% [markdown]
# save to csv test

# %% [markdown]
# NOTE: the correctness is a mean with all the runs
# Run 5 times

# %%
import csv
import copy

# CSV file name
csv_file = "alba_test.csv"

# Define the CSV file's header (column names) - updated to include all fields
header = ["PairID", "VarA", "VarB", "GroundTruth", "AccuracyACauseB", "AccuracyBCauseA", 
          "ConfidenceAB", "ConfidenceBA", "ReferencesAB", "ReferencesBA"]

# Write the data to the CSV file
with open(csv_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()
    for pair_id, values in results.items():
        # Convert reference lists to strings for CSV
        row = values.copy()
        # Rename keys to match header
        row['AccuracyACauseB'] = row.pop('CorrectACauseB')
        row['AccuracyBCauseA'] = row.pop('CorrectBCauseA')
        row['ReferencesAB'] = "; ".join(row['ReferencesAB']) if row['ReferencesAB'] else ""
        row['ReferencesBA'] = "; ".join(row['ReferencesBA']) if row['ReferencesBA'] else ""
        writer.writerow(row)

print(f"CSV file '{csv_file}' has been created.")
# Out:
# CSV file 'alba_test.csv' has been created.

# %% [markdown]
# ### Alba end test continue pywhyllm

# %%
# for pair_number, values in df.iterrows():

#         temp_dict = {}


#         temp_dict['llm_ab'] = modeler.suggest_relationship(variable_a=values['var1'], variable_b=values['var2'], description_a=values['var1_desc'], description_b=values['var2_desc'], strategy=Strategy.Straight)

#         temp_dict['llm_ba'] = modeler.suggest_relationship(variable_a=values['var2'], variable_b=values['var1'], description_a=values['var2_desc'], description_b=values['var1_desc'], strategy=Strategy.Straight)

#         llm_output[(pair_number, temperature, n)] = temp_dict
# Out:
# StitchWidget(initial_height='auto', initial_width='100%', srcdoc='<!doctype html>\n<html lang="en">\n<head>\n …
# StitchWidget(initial_height='auto', initial_width='100%', srcdoc='<!doctype html>\n<html lang="en">\n<head>\n …
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 10
#       6 temp_dict['llm_ab'] = modeler.suggest_relationship(variable_a=values['var1'], variable_b=values['var2'], description_a=values['var1_desc'], description_b=values['var2_desc'], strategy=Strategy.Straight)
#       8 temp_dict['llm_ba'] = modeler.suggest_relationship(variable_a=values['var2'], variable_b=values['var1'], description_a=values['var2_desc'], description_b=values['var1_desc'], strategy=Strategy.Straight)
# ---> 10 llm_output[(pair_number, temperature, n)] = temp_dict
#
# NameError: name 'temperature' is not defined

# %% [markdown]
# Running in all dataset (not run yet)

# %% [markdown]
# ##### Average LLM Output

# %%
# av_ab = 0
# av_ba = 0

# for i in range(5):
#     av_ab += llm_output[('pair0087', 0.3, i+1)]['llm_ab']
#     av_ba += llm_output[('pair0087', 0.3, i+1)]['llm_ba']

#     print(llm_output[('pair0087', 0.3, i+1)]['llm_ab'])
#     print(llm_output[('pair0087', 0.3, i+1)]['llm_ba'])

# av_ab = av_ab/5.0
# av_ba = av_ba/5.0

# print(av_ab)
# print(av_ba)

# %%
# for id in saved_pairs_info:

#     av_correct_ab = 0
#     av_correct_ba = 0

#     for i in range(5):
#         print(llm_output[(id, 0.3, i+1)]['llm_ab'])

# %%
# results : Dict = {}

# for id in saved_pairs_info:

#     av_correct_ab = 0
#     av_correct_ba = 0

#     for i in range(5):

#         if llm_output[(id, 0.3, i+1)]['llm_ab'] == 1 and saved_pairs_info[id]['ground_truth'] == " R":
#             av_correct_ab += 1
#         elif llm_output[(id, 0.3, i+1)]['llm_ab'] == 0 and saved_pairs_info[id]['ground_truth'] == " L":
#             av_correct_ab += 1

#         if llm_output[(id, 0.3, i+1)]['llm_ba'] == 1 and saved_pairs_info[id]['ground_truth'] == " L":
#             av_correct_ba += 1
#         elif llm_output[(id, 0.3, i+1)]['llm_ba'] == 0 and saved_pairs_info[id]['ground_truth'] == " R":
#             av_correct_ba += 1

#     av_correct_ab /= 5.0
#     av_correct_ba /= 5.0

#     temp : Dict = {}

#     temp['PairID'] = id
#     temp['CorrectACauseB'] = av_correct_ab
#     temp['CorrectBCauseA'] = av_correct_ba
#     temp['VarA'] = saved_pairs_info[id]['var1']
#     temp['VarB'] = saved_pairs_info[id]['var2']
#     temp['GroundTruth'] = saved_pairs_info[id]['ground_truth']

#     results[id] = temp
#     print(results[id])

# %% [markdown]
# #### Save to csv file

# %%
import csv
import copy

# CSV file name
csv_file = "gpt-4_results_straight_prompt_w_descriptions.csv"

# Define the CSV file's header (column names)
header = ["CorrectACauseB", "CorrectBCauseA", "PairID", "VarA", "VarB", "GroundTruth"]

# Write the data to the CSV file
with open(csv_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()
    for pair_id, values in results.items():
        writer.writerow(values)

print(f"CSV file '{csv_file}' has been created.")
